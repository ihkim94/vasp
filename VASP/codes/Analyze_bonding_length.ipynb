# %%
from pymatgen.io.vasp import Poscar
import matplotlib.pyplot as plt

poscar = Poscar.from_file("LNO_strain/POSCAR")
structure = poscar.structure

poscar_ta_05 = Poscar.from_file("LNO_strain/POSCAR_ta_05")
structure_ta_05 = poscar_ta_05.structure

poscar_ta_075 = Poscar.from_file("LNO_strain/POSCAR_ta_075")
structure_ta_075 = poscar_ta_075.structure

poscar_ta_1 = Poscar.from_file("LNO_strain/POSCAR_ta_1")
structure_ta_1 = poscar_ta_1.structure

poscar_ta_15 = Poscar.from_file("LNO_strain/POSCAR_ta_15")
structure_ta_15 = poscar_ta_15.structure

poscar_ta_2 = Poscar.from_file("LNO_strain/POSCAR_ta_2")
structure_ta_2 = poscar_ta_2.structure

poscar_ta_25 = Poscar.from_file("LNO_strain/POSCAR_ta_25")
structure_ta_25 = poscar_ta_25.structure

# def dist(i,j):
#     x = structure.get_distance(i,j)
#     return x
####
X = [1,2,3,4,5,6]
X1 = [1,2,3]
X2 = [4,5,6]
oct1_d6_0 = structure.get_distance(8, 18) ## Unit is angstrom
oct1_d5_0 = structure.get_distance(8, 19) ## Unit is angstrom
oct1_d4_0 = structure.get_distance(8, 20) ## Unit is angstrom
oct1_d3_0 = structure.get_distance(8, 27) ## Unit is angstrom
oct1_d2_0 = structure.get_distance(8, 28) ## Unit is angstrom
oct1_d1_0 = structure.get_distance(8, 29) ## Unit is angstrom

oct2_d2_0 = structure.get_distance(9, 18) ## Unit is angstrom
oct2_d3_0 = structure.get_distance(9, 19) ## Unit is angstrom
oct2_d1_0 = structure.get_distance(9, 20) ## Unit is angstrom
oct2_d5_0 = structure.get_distance(9, 21) ## Unit is angstrom
oct2_d6_0 = structure.get_distance(9, 22) ## Unit is angstrom
oct2_d4_0 = structure.get_distance(9, 23) ## Unit is angstrom

oct1_a6_0 = structure.get_angle(18, 8, 20)
oct1_a5_0 = structure.get_angle(19, 8, 18)
oct1_a4_0 = structure.get_angle(20, 8, 19)
oct1_a3_0 = structure.get_angle(27, 8, 29)
oct1_a2_0 = structure.get_angle(28, 8, 27)
oct1_a1_0 = structure.get_angle(29, 8, 28)

oct2_a6_0 = structure.get_angle(18, 9, 20)
oct2_a5_0 = structure.get_angle(18, 9, 19)
oct2_a4_0 = structure.get_angle(23, 9, 21)
oct2_a3_0 = structure.get_angle(19, 9, 20)
oct2_a2_0 = structure.get_angle(18, 9, 19)
oct2_a1_0 = structure.get_angle(18, 9, 20)

oct1_zero_strain_1 = [oct1_d1_0, oct1_d2_0, oct1_d3_0]
oct1_zero_strain_2 = [oct1_d4_0, oct1_d5_0, oct1_d6_0]
oct2_zero_strain_1 = [oct2_d1_0, oct2_d2_0, oct2_d3_0]
oct2_zero_strain_2 = [oct2_d4_0, oct2_d5_0, oct2_d6_0]

oct1_zero_strain_angle_1 = [oct1_a1_0, oct1_a2_0, oct1_a3_0]
oct1_zero_strain_angle_2 = [oct1_a4_0, oct1_a5_0, oct1_a6_0]
oct2_zero_strain_angle_1 = [oct2_a1_0, oct2_a2_0, oct2_a3_0]
oct2_zero_strain_angle_2 = [oct2_a4_0, oct2_a5_0, oct2_a6_0]

####
####
oct1_d6_ta_05 = structure_ta_05.get_distance(8, 18) ## Unit is angstrom
oct1_d5_ta_05 = structure_ta_05.get_distance(8, 19) ## Unit is angstrom
oct1_d4_ta_05 = structure_ta_05.get_distance(8, 20) ## Unit is angstrom
oct1_d3_ta_05 = structure_ta_05.get_distance(8, 27) ## Unit is angstrom
oct1_d2_ta_05 = structure_ta_05.get_distance(8, 28) ## Unit is angstrom
oct1_d1_ta_05 = structure_ta_05.get_distance(8, 29) ## Unit is angstrom

oct2_d2_ta_05 = structure_ta_05.get_distance(9, 18) ## Unit is angstrom
oct2_d3_ta_05 = structure_ta_05.get_distance(9, 19) ## Unit is angstrom
oct2_d1_ta_05 = structure_ta_05.get_distance(9, 20) ## Unit is angstrom
oct2_d5_ta_05 = structure_ta_05.get_distance(9, 21) ## Unit is angstrom
oct2_d6_ta_05 = structure_ta_05.get_distance(9, 22) ## Unit is angstrom
oct2_d4_ta_05 = structure_ta_05.get_distance(9, 23) ## Unit is angstrom

oct1_ta_05 = [oct1_d1_ta_05, oct1_d2_ta_05, oct1_d3_ta_05, oct1_d4_ta_05, oct1_d5_ta_05, oct1_d6_ta_05]
oct2_ta_05 = [oct2_d1_ta_05, oct2_d2_ta_05, oct2_d3_ta_05, oct2_d4_ta_05, oct2_d5_ta_05, oct2_d6_ta_05]
####
####
oct1_d6_ta_075 = structure_ta_075.get_distance(8, 18) ## Unit is angstrom
oct1_d5_ta_075 = structure_ta_075.get_distance(8, 19) ## Unit is angstrom
oct1_d4_ta_075 = structure_ta_075.get_distance(8, 20) ## Unit is angstrom
oct1_d3_ta_075 = structure_ta_075.get_distance(8, 27) ## Unit is angstrom
oct1_d2_ta_075 = structure_ta_075.get_distance(8, 28) ## Unit is angstrom
oct1_d1_ta_075 = structure_ta_075.get_distance(8, 29) ## Unit is angstrom

oct2_d2_ta_075 = structure_ta_075.get_distance(9, 18) ## Unit is angstrom
oct2_d3_ta_075 = structure_ta_075.get_distance(9, 19) ## Unit is angstrom
oct2_d1_ta_075 = structure_ta_075.get_distance(9, 20) ## Unit is angstrom
oct2_d5_ta_075 = structure_ta_075.get_distance(9, 21) ## Unit is angstrom
oct2_d6_ta_075 = structure_ta_075.get_distance(9, 22) ## Unit is angstrom
oct2_d4_ta_075 = structure_ta_075.get_distance(9, 23) ## Unit is angstrom

oct1_ta_075 = [oct1_d1_ta_075, oct1_d2_ta_075, oct1_d3_ta_075, oct1_d4_ta_075, oct1_d5_ta_075, oct1_d6_ta_075]
oct2_ta_075 = [oct2_d1_ta_075, oct2_d2_ta_075, oct2_d3_ta_075, oct2_d4_ta_075, oct2_d5_ta_075, oct2_d6_ta_075]
####
####
oct1_d6_ta_1 = structure_ta_1.get_distance(8, 18) ## Unit is angstrom
oct1_d5_ta_1 = structure_ta_1.get_distance(8, 19) ## Unit is angstrom
oct1_d4_ta_1 = structure_ta_1.get_distance(8, 20) ## Unit is angstrom
oct1_d3_ta_1 = structure_ta_1.get_distance(8, 27) ## Unit is angstrom
oct1_d2_ta_1 = structure_ta_1.get_distance(8, 28) ## Unit is angstrom
oct1_d1_ta_1 = structure_ta_1.get_distance(8, 29) ## Unit is angstrom

oct2_d2_ta_1 = structure_ta_1.get_distance(9, 18) ## Unit is angstrom
oct2_d3_ta_1 = structure_ta_1.get_distance(9, 19) ## Unit is angstrom
oct2_d1_ta_1 = structure_ta_1.get_distance(9, 20) ## Unit is angstrom
oct2_d5_ta_1 = structure_ta_1.get_distance(9, 21) ## Unit is angstrom
oct2_d6_ta_1 = structure_ta_1.get_distance(9, 22) ## Unit is angstrom
oct2_d4_ta_1 = structure_ta_1.get_distance(9, 23) ## Unit is angstrom

oct1_ta_1 = [oct1_d1_ta_1, oct1_d2_ta_1, oct1_d3_ta_1, oct1_d4_ta_1, oct1_d5_ta_1, oct1_d6_ta_1]
oct2_ta_1 = [oct2_d1_ta_1, oct2_d2_ta_1, oct2_d3_ta_1, oct2_d4_ta_1, oct2_d5_ta_1, oct2_d6_ta_1]
####
####
oct1_d6_ta_15 = structure_ta_15.get_distance(8, 18) ## Unit is angstrom
oct1_d5_ta_15 = structure_ta_15.get_distance(8, 19) ## Unit is angstrom
oct1_d4_ta_15 = structure_ta_15.get_distance(8, 20) ## Unit is angstrom
oct1_d3_ta_15 = structure_ta_15.get_distance(8, 27) ## Unit is angstrom
oct1_d2_ta_15 = structure_ta_15.get_distance(8, 28) ## Unit is angstrom
oct1_d1_ta_15 = structure_ta_15.get_distance(8, 29) ## Unit is angstrom

oct2_d2_ta_15 = structure_ta_15.get_distance(9, 18) ## Unit is angstrom
oct2_d3_ta_15 = structure_ta_15.get_distance(9, 19) ## Unit is angstrom
oct2_d1_ta_15 = structure_ta_15.get_distance(9, 20) ## Unit is angstrom
oct2_d5_ta_15 = structure_ta_15.get_distance(9, 21) ## Unit is angstrom
oct2_d6_ta_15 = structure_ta_15.get_distance(9, 22) ## Unit is angstrom
oct2_d4_ta_15 = structure_ta_15.get_distance(9, 23) ## Unit is angstrom

oct1_ta_15 = [oct1_d1_ta_15, oct1_d2_ta_15, oct1_d3_ta_15, oct1_d4_ta_15, oct1_d5_ta_15, oct1_d6_ta_15]
oct2_ta_15 = [oct2_d1_ta_15, oct2_d2_ta_15, oct2_d3_ta_15, oct2_d4_ta_15, oct2_d5_ta_15, oct2_d6_ta_15]
####
####
oct1_d6_ta_2 = structure_ta_2.get_distance(8, 18) ## Unit is angstrom
oct1_d5_ta_2 = structure_ta_2.get_distance(8, 19) ## Unit is angstrom
oct1_d4_ta_2 = structure_ta_2.get_distance(8, 20) ## Unit is angstrom
oct1_d3_ta_2 = structure_ta_2.get_distance(8, 27) ## Unit is angstrom
oct1_d2_ta_2 = structure_ta_2.get_distance(8, 28) ## Unit is angstrom
oct1_d1_ta_2 = structure_ta_2.get_distance(8, 29) ## Unit is angstrom

oct2_d2_ta_2 = structure_ta_2.get_distance(9, 18) ## Unit is angstrom
oct2_d3_ta_2 = structure_ta_2.get_distance(9, 19) ## Unit is angstrom
oct2_d1_ta_2 = structure_ta_2.get_distance(9, 20) ## Unit is angstrom
oct2_d5_ta_2 = structure_ta_2.get_distance(9, 21) ## Unit is angstrom
oct2_d6_ta_2 = structure_ta_2.get_distance(9, 22) ## Unit is angstrom
oct2_d4_ta_2 = structure_ta_2.get_distance(9, 23) ## Unit is angstrom

oct1_ta_2 = [oct1_d1_ta_2, oct1_d2_ta_2, oct1_d3_ta_2, oct1_d4_ta_2, oct1_d5_ta_2, oct1_d6_ta_2]
oct2_ta_2 = [oct2_d1_ta_2, oct2_d2_ta_2, oct2_d3_ta_2, oct2_d4_ta_2, oct2_d5_ta_2, oct2_d6_ta_2]
####
####
oct1_d6_ta_25 = structure_ta_25.get_distance(8, 18) ## Unit is angstrom
oct1_d5_ta_25 = structure_ta_25.get_distance(8, 19) ## Unit is angstrom
oct1_d4_ta_25 = structure_ta_25.get_distance(8, 20) ## Unit is angstrom
oct1_d3_ta_25 = structure_ta_25.get_distance(8, 27) ## Unit is angstrom
oct1_d2_ta_25 = structure_ta_25.get_distance(8, 28) ## Unit is angstrom
oct1_d1_ta_25 = structure_ta_25.get_distance(8, 29) ## Unit is angstrom

oct2_d2_ta_25 = structure_ta_25.get_distance(9, 18) ## Unit is angstrom
oct2_d3_ta_25 = structure_ta_25.get_distance(9, 19) ## Unit is angstrom
oct2_d1_ta_25 = structure_ta_25.get_distance(9, 20) ## Unit is angstrom
oct2_d5_ta_25 = structure_ta_25.get_distance(9, 21) ## Unit is angstrom
oct2_d6_ta_25 = structure_ta_25.get_distance(9, 22) ## Unit is angstrom
oct2_d4_ta_25 = structure_ta_25.get_distance(9, 23) ## Unit is angstrom

oct1_ta_25 = [oct1_d1_ta_25, oct1_d2_ta_25, oct1_d3_ta_25, oct1_d4_ta_25, oct1_d5_ta_25, oct1_d6_ta_25]
oct2_ta_25 = [oct2_d1_ta_25, oct2_d2_ta_25, oct2_d3_ta_25, oct2_d4_ta_25, oct2_d5_ta_25, oct2_d6_ta_25]
####
####
####
####from pymatgen.io.vasp import Poscar
import matplotlib.pyplot as plt

poscar = Poscar.from_file("LNO_strain/POSCAR")
structure = poscar.structure

poscar_tc_05 = Poscar.from_file("LNO_strain/POSCAR_tc_05")
structure_tc_05 = poscar_tc_05.structure

poscar_tc_075 = Poscar.from_file("LNO_strain/POSCAR_tc_075")
structure_tc_075 = poscar_tc_075.structure

poscar_tc_1 = Poscar.from_file("LNO_strain/POSCAR_tc_1")
structure_tc_1 = poscar_tc_1.structure

poscar_tc_15 = Poscar.from_file("LNO_strain/POSCAR_tc_15")
structure_tc_15 = poscar_tc_15.structure

poscar_tc_2 = Poscar.from_file("LNO_strain/POSCAR_tc_2")
structure_tc_2 = poscar_tc_2.structure

poscar_tc_25 = Poscar.from_file("LNO_strain/POSCAR_tc_25")
structure_tc_25 = poscar_tc_25.structure

# def dist(i,j):
#     x = structure.get_distance(i,j)
#     return x
####
X = [1,2,3,4,5,6]
X1 = [1,2,3]
X2 = [4,5,6]
oct1_d6_0 = structure.get_distance(8, 18) ## Unit is angstrom
oct1_d5_0 = structure.get_distance(8, 19) ## Unit is angstrom
oct1_d4_0 = structure.get_distance(8, 20) ## Unit is angstrom
oct1_d3_0 = structure.get_distance(8, 27) ## Unit is angstrom
oct1_d2_0 = structure.get_distance(8, 28) ## Unit is angstrom
oct1_d1_0 = structure.get_distance(8, 29) ## Unit is angstrom

oct2_d2_0 = structure.get_distance(9, 18) ## Unit is angstrom
oct2_d3_0 = structure.get_distance(9, 19) ## Unit is angstrom
oct2_d1_0 = structure.get_distance(9, 20) ## Unit is angstrom
oct2_d5_0 = structure.get_distance(9, 21) ## Unit is angstrom
oct2_d6_0 = structure.get_distance(9, 22) ## Unit is angstrom
oct2_d4_0 = structure.get_distance(9, 23) ## Unit is angstrom

oct1_zero_strain_1 = [oct1_d1_0, oct1_d2_0, oct1_d3_0]
oct1_zero_strain_2 = [oct1_d4_0, oct1_d5_0, oct1_d6_0]
oct2_zero_strain_1 = [oct2_d1_0, oct2_d2_0, oct2_d3_0]
oct2_zero_strain_2 = [oct2_d4_0, oct2_d5_0, oct2_d6_0]

####
####
oct1_d6_tc_05 = structure_tc_05.get_distance(8, 18) ## Unit is angstrom
oct1_d5_tc_05 = structure_tc_05.get_distance(8, 19) ## Unit is angstrom
oct1_d4_tc_05 = structure_tc_05.get_distance(8, 20) ## Unit is angstrom
oct1_d3_tc_05 = structure_tc_05.get_distance(8, 27) ## Unit is angstrom
oct1_d2_tc_05 = structure_tc_05.get_distance(8, 28) ## Unit is angstrom
oct1_d1_tc_05 = structure_tc_05.get_distance(8, 29) ## Unit is angstrom

oct2_d2_tc_05 = structure_tc_05.get_distance(9, 18) ## Unit is angstrom
oct2_d3_tc_05 = structure_tc_05.get_distance(9, 19) ## Unit is angstrom
oct2_d1_tc_05 = structure_tc_05.get_distance(9, 20) ## Unit is angstrom
oct2_d5_tc_05 = structure_tc_05.get_distance(9, 21) ## Unit is angstrom
oct2_d6_tc_05 = structure_tc_05.get_distance(9, 22) ## Unit is angstrom
oct2_d4_tc_05 = structure_tc_05.get_distance(9, 23) ## Unit is angstrom

oct1_tc_05 = [oct1_d1_tc_05, oct1_d2_tc_05, oct1_d3_tc_05, oct1_d4_tc_05, oct1_d5_tc_05, oct1_d6_tc_05]
oct2_tc_05 = [oct2_d1_tc_05, oct2_d2_tc_05, oct2_d3_tc_05, oct2_d4_tc_05, oct2_d5_tc_05, oct2_d6_tc_05]

oct1_d6_tc_075 = structure_tc_075.get_distance(8, 18) ## Unit is angstrom
oct1_d5_tc_075 = structure_tc_075.get_distance(8, 19) ## Unit is angstrom
oct1_d4_tc_075 = structure_tc_075.get_distance(8, 20) ## Unit is angstrom
oct1_d3_tc_075 = structure_tc_075.get_distance(8, 27) ## Unit is angstrom
oct1_d2_tc_075 = structure_tc_075.get_distance(8, 28) ## Unit is angstrom
oct1_d1_tc_075 = structure_tc_075.get_distance(8, 29) ## Unit is angstrom

oct2_d2_tc_075 = structure_tc_075.get_distance(9, 18) ## Unit is angstrom
oct2_d3_tc_075 = structure_tc_075.get_distance(9, 19) ## Unit is angstrom
oct2_d1_tc_075 = structure_tc_075.get_distance(9, 20) ## Unit is angstrom
oct2_d5_tc_075 = structure_tc_075.get_distance(9, 21) ## Unit is angstrom
oct2_d6_tc_075 = structure_tc_075.get_distance(9, 22) ## Unit is angstrom
oct2_d4_tc_075 = structure_tc_075.get_distance(9, 23) ## Unit is angstrom

oct1_tc_075 = [oct1_d1_tc_075, oct1_d2_tc_075, oct1_d3_tc_075, oct1_d4_tc_075, oct1_d5_tc_075, oct1_d6_tc_075]
oct2_tc_075 = [oct2_d1_tc_075, oct2_d2_tc_075, oct2_d3_tc_075, oct2_d4_tc_075, oct2_d5_tc_075, oct2_d6_tc_075]

oct1_d6_tc_1 = structure_tc_1.get_distance(8, 18)  # Unit is angstrom
oct1_d5_tc_1 = structure_tc_1.get_distance(8, 19)  # Unit is angstrom
oct1_d4_tc_1 = structure_tc_1.get_distance(8, 20)  # Unit is angstrom
oct1_d3_tc_1 = structure_tc_1.get_distance(8, 27)  # Unit is angstrom
oct1_d2_tc_1 = structure_tc_1.get_distance(8, 28)  # Unit is angstrom
oct1_d1_tc_1 = structure_tc_1.get_distance(8, 29)  # Unit is angstrom

oct2_d2_tc_1 = structure_tc_1.get_distance(9, 18)  # Unit is angstrom
oct2_d3_tc_1 = structure_tc_1.get_distance(9, 19)  # Unit is angstrom
oct2_d1_tc_1 = structure_tc_1.get_distance(9, 20)  # Unit is angstrom
oct2_d5_tc_1 = structure_tc_1.get_distance(9, 21)  # Unit is angstrom
oct2_d6_tc_1 = structure_tc_1.get_distance(9, 22)  # Unit is angstrom
oct2_d4_tc_1 = structure_tc_1.get_distance(9, 23)  # Unit is angstrom

oct1_tc_1 = [oct1_d1_tc_1, oct1_d2_tc_1, oct1_d3_tc_1, oct1_d4_tc_1, oct1_d5_tc_1, oct1_d6_tc_1]
oct2_tc_1 = [oct2_d1_tc_1, oct2_d2_tc_1, oct2_d3_tc_1, oct2_d4_tc_1, oct2_d5_tc_1, oct2_d6_tc_1]

oct1_d6_tc_15 = structure_tc_15.get_distance(8, 18)  # Unit is angstrom
oct1_d5_tc_15 = structure_tc_15.get_distance(8, 19)  # Unit is angstrom
oct1_d4_tc_15 = structure_tc_15.get_distance(8, 20)  # Unit is angstrom
oct1_d3_tc_15 = structure_tc_15.get_distance(8, 27)  # Unit is angstrom
oct1_d2_tc_15 = structure_tc_15.get_distance(8, 28)  # Unit is angstrom
oct1_d1_tc_15 = structure_tc_15.get_distance(8, 29)  # Unit is angstrom

oct2_d2_tc_15 = structure_tc_15.get_distance(9, 18)  # Unit is angstrom
oct2_d3_tc_15 = structure_tc_15.get_distance(9, 19)  # Unit is angstrom
oct2_d1_tc_15 = structure_tc_15.get_distance(9, 20)  # Unit is angstrom
oct2_d5_tc_15 = structure_tc_15.get_distance(9, 21)  # Unit is angstrom
oct2_d6_tc_15 = structure_tc_15.get_distance(9, 22)  # Unit is angstrom
oct2_d4_tc_15 = structure_tc_15.get_distance(9, 23)  # Unit is angstrom

oct1_tc_15 = [oct1_d1_tc_15, oct1_d2_tc_15, oct1_d3_tc_15, oct1_d4_tc_15, oct1_d5_tc_15, oct1_d6_tc_15]
oct2_tc_15 = [oct2_d1_tc_15, oct2_d2_tc_15, oct2_d3_tc_15, oct2_d4_tc_15, oct2_d5_tc_15, oct2_d6_tc_15]

oct1_d6_tc_2 = structure_tc_2.get_distance(8, 18)  # Unit is angstrom
oct1_d5_tc_2 = structure_tc_2.get_distance(8, 19)  # Unit is angstrom
oct1_d4_tc_2 = structure_tc_2.get_distance(8, 20)  # Unit is angstrom
oct1_d3_tc_2 = structure_tc_2.get_distance(8, 27)  # Unit is angstrom
oct1_d2_tc_2 = structure_tc_2.get_distance(8, 28)  # Unit is angstrom
oct1_d1_tc_2 = structure_tc_2.get_distance(8, 29)  # Unit is angstrom

oct2_d2_tc_2 = structure_tc_2.get_distance(9, 18)  # Unit is angstrom
oct2_d3_tc_2 = structure_tc_2.get_distance(9, 19)  # Unit is angstrom
oct2_d1_tc_2 = structure_tc_2.get_distance(9, 20)  # Unit is angstrom
oct2_d5_tc_2 = structure_tc_2.get_distance(9, 21)  # Unit is angstrom
oct2_d6_tc_2 = structure_tc_2.get_distance(9, 22)  # Unit is angstrom
oct2_d4_tc_2 = structure_tc_2.get_distance(9, 23)  # Unit is angstrom

oct1_tc_2 = [oct1_d1_tc_2, oct1_d2_tc_2, oct1_d3_tc_2, oct1_d4_tc_2, oct1_d5_tc_2, oct1_d6_tc_2]
oct2_tc_2 = [oct2_d1_tc_2, oct2_d2_tc_2, oct2_d3_tc_2, oct2_d4_tc_2, oct2_d5_tc_2, oct2_d6_tc_2]

oct1_d6_tc_25 = structure_tc_25.get_distance(8, 18)  # Unit is angstrom
oct1_d5_tc_25 = structure_tc_25.get_distance(8, 19)  # Unit is angstrom
oct1_d4_tc_25 = structure_tc_25.get_distance(8, 20)  # Unit is angstrom
oct1_d3_tc_25 = structure_tc_25.get_distance(8, 27)  # Unit is angstrom
oct1_d2_tc_25 = structure_tc_25.get_distance(8, 28)  # Unit is angstrom
oct1_d1_tc_25 = structure_tc_25.get_distance(8, 29)  # Unit is angstrom

oct2_d2_tc_25 = structure_tc_25.get_distance(9, 18)  # Unit is angstrom
oct2_d3_tc_25 = structure_tc_25.get_distance(9, 19)  # Unit is angstrom
oct2_d1_tc_25 = structure_tc_25.get_distance(9, 20)  # Unit is angstrom
oct2_d5_tc_25 = structure_tc_25.get_distance(9, 21)  # Unit is angstrom
oct2_d6_tc_25 = structure_tc_25.get_distance(9, 22)  # Unit is angstrom
oct2_d4_tc_25 = structure_tc_25.get_distance(9, 23)  # Unit is angstrom

oct1_tc_25 = [oct1_d1_tc_25, oct1_d2_tc_25, oct1_d3_tc_25, oct1_d4_tc_25, oct1_d5_tc_25, oct1_d6_tc_25]
oct2_tc_25 = [oct2_d1_tc_25, oct2_d2_tc_25, oct2_d3_tc_25, oct2_d4_tc_25, oct2_d5_tc_25, oct2_d6_tc_25]

####
####
####
####from pymatgen.io.vasp import Poscar
import matplotlib.pyplot as plt

poscar = Poscar.from_file("LNO_strain/POSCAR")
structure = poscar.structure

poscar_sh_05 = Poscar.from_file("LNO_strain/POSCAR_sh_05")
structure_sh_05 = poscar_sh_05.structure

poscar_sh_075 = Poscar.from_file("LNO_strain/POSCAR_sh_075")
structure_sh_075 = poscar_sh_075.structure

poscar_sh_1 = Poscar.from_file("LNO_strain/POSCAR_sh_1")
structure_sh_1 = poscar_sh_1.structure

poscar_sh_15 = Poscar.from_file("LNO_strain/POSCAR_sh_15")
structure_sh_15 = poscar_sh_15.structure

poscar_sh_2 = Poscar.from_file("LNO_strain/POSCAR_sh_2")
structure_sh_2 = poscar_sh_2.structure

poscar_sh_25 = Poscar.from_file("LNO_strain/POSCAR_sh_25")
structure_sh_25 = poscar_sh_25.structure

# def dist(i,j):
#     x = structure.get_distance(i,j)
#     return x
####
X = [1,2,3,4,5,6]
X1 = [1,2,3]
X2 = [4,5,6]
oct1_d6_0 = structure.get_distance(8, 18) ## Unit is angstrom
oct1_d5_0 = structure.get_distance(8, 19) ## Unit is angstrom
oct1_d4_0 = structure.get_distance(8, 20) ## Unit is angstrom
oct1_d3_0 = structure.get_distance(8, 27) ## Unit is angstrom
oct1_d2_0 = structure.get_distance(8, 28) ## Unit is angstrom
oct1_d1_0 = structure.get_distance(8, 29) ## Unit is angstrom

oct2_d2_0 = structure.get_distance(9, 18) ## Unit is angstrom
oct2_d3_0 = structure.get_distance(9, 19) ## Unit is angstrom
oct2_d1_0 = structure.get_distance(9, 20) ## Unit is angstrom
oct2_d5_0 = structure.get_distance(9, 21) ## Unit is angstrom
oct2_d6_0 = structure.get_distance(9, 22) ## Unit is angstrom
oct2_d4_0 = structure.get_distance(9, 23) ## Unit is angstrom

oct1_zero_strain_1 = [oct1_d1_0, oct1_d2_0, oct1_d3_0]
oct1_zero_strain_2 = [oct1_d4_0, oct1_d5_0, oct1_d6_0]
oct2_zero_strain_1 = [oct2_d1_0, oct2_d2_0, oct2_d3_0]
oct2_zero_strain_2 = [oct2_d4_0, oct2_d5_0, oct2_d6_0]

oct1_d6_sh_05 = structure_sh_05.get_distance(8, 18) ## Unit is angstrom
oct1_d5_sh_05 = structure_sh_05.get_distance(8, 19) ## Unit is angstrom
oct1_d4_sh_05 = structure_sh_05.get_distance(8, 20) ## Unit is angstrom
oct1_d3_sh_05 = structure_sh_05.get_distance(8, 27) ## Unit is angstrom
oct1_d2_sh_05 = structure_sh_05.get_distance(8, 28) ## Unit is angstrom
oct1_d1_sh_05 = structure_sh_05.get_distance(8, 29) ## Unit is angstrom

oct2_d2_sh_05 = structure_sh_05.get_distance(9, 18) ## Unit is angstrom
oct2_d3_sh_05 = structure_sh_05.get_distance(9, 19) ## Unit is angstrom
oct2_d1_sh_05 = structure_sh_05.get_distance(9, 20) ## Unit is angstrom
oct2_d5_sh_05 = structure_sh_05.get_distance(9, 21) ## Unit is angstrom
oct2_d6_sh_05 = structure_sh_05.get_distance(9, 22) ## Unit is angstrom
oct2_d4_sh_05 = structure_sh_05.get_distance(9, 23) ## Unit is angstrom

oct1_sh_05 = [oct1_d1_sh_05, oct1_d2_sh_05, oct1_d3_sh_05, oct1_d4_sh_05, oct1_d5_sh_05, oct1_d6_sh_05]
oct2_sh_05 = [oct2_d1_sh_05, oct2_d2_sh_05, oct2_d3_sh_05, oct2_d4_sh_05, oct2_d5_sh_05, oct2_d6_sh_05]

oct1_d6_sh_075 = structure_sh_075.get_distance(8, 18) ## Unit is angstrom
oct1_d5_sh_075 = structure_sh_075.get_distance(8, 19) ## Unit is angstrom
oct1_d4_sh_075 = structure_sh_075.get_distance(8, 20) ## Unit is angstrom
oct1_d3_sh_075 = structure_sh_075.get_distance(8, 27) ## Unit is angstrom
oct1_d2_sh_075 = structure_sh_075.get_distance(8, 28) ## Unit is angstrom
oct1_d1_sh_075 = structure_sh_075.get_distance(8, 29) ## Unit is angstrom

oct2_d2_sh_075 = structure_sh_075.get_distance(9, 18) ## Unit is angstrom
oct2_d3_sh_075 = structure_sh_075.get_distance(9, 19) ## Unit is angstrom
oct2_d1_sh_075 = structure_sh_075.get_distance(9, 20) ## Unit is angstrom
oct2_d5_sh_075 = structure_sh_075.get_distance(9, 21) ## Unit is angstrom
oct2_d6_sh_075 = structure_sh_075.get_distance(9, 22) ## Unit is angstrom
oct2_d4_sh_075 = structure_sh_075.get_distance(9, 23) ## Unit is angstrom

oct1_sh_075 = [oct1_d1_sh_075, oct1_d2_sh_075, oct1_d3_sh_075, oct1_d4_sh_075, oct1_d5_sh_075, oct1_d6_sh_075]
oct2_sh_075 = [oct2_d1_sh_075, oct2_d2_sh_075, oct2_d3_sh_075, oct2_d4_sh_075, oct2_d5_sh_075, oct2_d6_sh_075]

oct1_d6_sh_1 = structure_sh_1.get_distance(8, 18)  # Unit is angstrom
oct1_d5_sh_1 = structure_sh_1.get_distance(8, 19)  # Unit is angstrom
oct1_d4_sh_1 = structure_sh_1.get_distance(8, 20)  # Unit is angstrom
oct1_d3_sh_1 = structure_sh_1.get_distance(8, 27)  # Unit is angstrom
oct1_d2_sh_1 = structure_sh_1.get_distance(8, 28)  # Unit is angstrom
oct1_d1_sh_1 = structure_sh_1.get_distance(8, 29)  # Unit is angstrom

oct2_d2_sh_1 = structure_sh_1.get_distance(9, 18)  # Unit is angstrom
oct2_d3_sh_1 = structure_sh_1.get_distance(9, 19)  # Unit is angstrom
oct2_d1_sh_1 = structure_sh_1.get_distance(9, 20)  # Unit is angstrom
oct2_d5_sh_1 = structure_sh_1.get_distance(9, 21)  # Unit is angstrom
oct2_d6_sh_1 = structure_sh_1.get_distance(9, 22)  # Unit is angstrom
oct2_d4_sh_1 = structure_sh_1.get_distance(9, 23)  # Unit is angstrom

oct1_sh_1 = [oct1_d1_sh_1, oct1_d2_sh_1, oct1_d3_sh_1, oct1_d4_sh_1, oct1_d5_sh_1, oct1_d6_sh_1]
oct2_sh_1 = [oct2_d1_sh_1, oct2_d2_sh_1, oct2_d3_sh_1, oct2_d4_sh_1, oct2_d5_sh_1, oct2_d6_sh_1]

oct1_d6_sh_15 = structure_sh_15.get_distance(8, 18)  # Unit is angstrom
oct1_d5_sh_15 = structure_sh_15.get_distance(8, 19)  # Unit is angstrom
oct1_d4_sh_15 = structure_sh_15.get_distance(8, 20)  # Unit is angstrom
oct1_d3_sh_15 = structure_sh_15.get_distance(8, 27)  # Unit is angstrom
oct1_d2_sh_15 = structure_sh_15.get_distance(8, 28)  # Unit is angstrom
oct1_d1_sh_15 = structure_sh_15.get_distance(8, 29)  # Unit is angstrom

oct2_d2_sh_15 = structure_sh_15.get_distance(9, 18)  # Unit is angstrom
oct2_d3_sh_15 = structure_sh_15.get_distance(9, 19)  # Unit is angstrom
oct2_d1_sh_15 = structure_sh_15.get_distance(9, 20)  # Unit is angstrom
oct2_d5_sh_15 = structure_sh_15.get_distance(9, 21)  # Unit is angstrom
oct2_d6_sh_15 = structure_sh_15.get_distance(9, 22)  # Unit is angstrom
oct2_d4_sh_15 = structure_sh_15.get_distance(9, 23)  # Unit is angstrom

oct1_sh_15 = [oct1_d1_sh_15, oct1_d2_sh_15, oct1_d3_sh_15, oct1_d4_sh_15, oct1_d5_sh_15, oct1_d6_sh_15]
oct2_sh_15 = [oct2_d1_sh_15, oct2_d2_sh_15, oct2_d3_sh_15, oct2_d4_sh_15, oct2_d5_sh_15, oct2_d6_sh_15]

oct1_d6_sh_2 = structure_sh_2.get_distance(8, 18)  # Unit is angstrom
oct1_d5_sh_2 = structure_sh_2.get_distance(8, 19)  # Unit is angstrom
oct1_d4_sh_2 = structure_sh_2.get_distance(8, 20)  # Unit is angstrom
oct1_d3_sh_2 = structure_sh_2.get_distance(8, 27)  # Unit is angstrom
oct1_d2_sh_2 = structure_sh_2.get_distance(8, 28)  # Unit is angstrom
oct1_d1_sh_2 = structure_sh_2.get_distance(8, 29)  # Unit is angstrom

oct2_d2_sh_2 = structure_sh_2.get_distance(9, 18)  # Unit is angstrom
oct2_d3_sh_2 = structure_sh_2.get_distance(9, 19)  # Unit is angstrom
oct2_d1_sh_2 = structure_sh_2.get_distance(9, 20)  # Unit is angstrom
oct2_d5_sh_2 = structure_sh_2.get_distance(9, 21)  # Unit is angstrom
oct2_d6_sh_2 = structure_sh_2.get_distance(9, 22)  # Unit is angstrom
oct2_d4_sh_2 = structure_sh_2.get_distance(9, 23)  # Unit is angstrom

oct1_sh_2 = [oct1_d1_sh_2, oct1_d2_sh_2, oct1_d3_sh_2, oct1_d4_sh_2, oct1_d5_sh_2, oct1_d6_sh_2]
oct2_sh_2 = [oct2_d1_sh_2, oct2_d2_sh_2, oct2_d3_sh_2, oct2_d4_sh_2, oct2_d5_sh_2, oct2_d6_sh_2]

oct1_d6_sh_25 = structure_sh_25.get_distance(8, 18)  # Unit is angstrom
oct1_d5_sh_25 = structure_sh_25.get_distance(8, 19)  # Unit is angstrom
oct1_d4_sh_25 = structure_sh_25.get_distance(8, 20)  # Unit is angstrom
oct1_d3_sh_25 = structure_sh_25.get_distance(8, 27)  # Unit is angstrom
oct1_d2_sh_25 = structure_sh_25.get_distance(8, 28)  # Unit is angstrom
oct1_d1_sh_25 = structure_sh_25.get_distance(8, 29)  # Unit is angstrom

oct2_d2_sh_25 = structure_sh_25.get_distance(9, 18)  # Unit is angstrom
oct2_d3_sh_25 = structure_sh_25.get_distance(9, 19)  # Unit is angstrom
oct2_d1_sh_25 = structure_sh_25.get_distance(9, 20)  # Unit is angstrom
oct2_d5_sh_25 = structure_sh_25.get_distance(9, 21)  # Unit is angstrom
oct2_d6_sh_25 = structure_sh_25.get_distance(9, 22)  # Unit is angstrom
oct2_d4_sh_25 = structure_sh_25.get_distance(9, 23)  # Unit is angstrom

oct1_sh_25 = [oct1_d1_sh_25, oct1_d2_sh_25, oct1_d3_sh_25, oct1_d4_sh_25, oct1_d5_sh_25, oct1_d6_sh_25]
oct2_sh_25 = [oct2_d1_sh_25, oct2_d2_sh_25, oct2_d3_sh_25, oct2_d4_sh_25, oct2_d5_sh_25, oct2_d6_sh_25]


print(oct1_a1_0)
print(oct1_a4_0)
# Out:
# 80.3337061116783
# 99.4928765522543

# %%
import numpy as np

fig, ax = plt.subplots(ncols=3, figsize=(20, 12))
fig.dpi = 100
strain = [0.0, 0.5, 0.75, 1.0, 1.5, 2.0, 2.5]
# oct1_d1_ta_ch = [0.0, np.sqrt((oct1_d1_ta_05 - oct1_d1_0)**2), np.sqrt((oct1_d1_ta_075 - oct1_d1_0)**2), np.sqrt((oct1_d1_ta_1 - oct1_d1_0)**2), np.sqrt((oct1_d1_ta_15 - oct1_d1_0)**2), np.sqrt((oct1_d1_ta_2 - oct1_d1_0)**2), np.sqrt((oct1_d1_ta_25 - oct1_d1_0)**2)]
# oct1_d2_ta_ch = [0.0, np.sqrt((oct1_d2_ta_05 - oct1_d2_0)**2), np.sqrt((oct1_d2_ta_075 - oct1_d2_0)**2), np.sqrt((oct1_d2_ta_1 - oct1_d2_0)**2), np.sqrt((oct1_d2_ta_15 - oct1_d2_0)**2), np.sqrt((oct1_d2_ta_2 - oct1_d2_0)**2), np.sqrt((oct1_d2_ta_25 - oct1_d2_0)**2)]
# oct1_d3_ta_ch = [0.0, np.sqrt((oct1_d3_ta_05 - oct1_d3_0)**2), np.sqrt((oct1_d3_ta_075 - oct1_d3_0)**2), np.sqrt((oct1_d3_ta_1 - oct1_d3_0)**2), np.sqrt((oct1_d3_ta_15 - oct1_d3_0)**2), np.sqrt((oct1_d3_ta_2 - oct1_d3_0)**2), np.sqrt((oct1_d3_ta_25 - oct1_d3_0)**2)]
# oct1_d4_ta_ch = [0.0, np.sqrt((oct1_d4_ta_05 - oct1_d4_0)**2), np.sqrt((oct1_d4_ta_075 - oct1_d4_0)**2), np.sqrt((oct1_d4_ta_1 - oct1_d4_0)**2), np.sqrt((oct1_d4_ta_15 - oct1_d4_0)**2), np.sqrt((oct1_d4_ta_2 - oct1_d4_0)**2), np.sqrt((oct1_d4_ta_25 - oct1_d4_0)**2)]
# oct1_d5_ta_ch = [0.0, np.sqrt((oct1_d5_ta_05 - oct1_d5_0)**2), np.sqrt((oct1_d5_ta_075 - oct1_d5_0)**2), np.sqrt((oct1_d5_ta_1 - oct1_d5_0)**2), np.sqrt((oct1_d5_ta_15 - oct1_d5_0)**2), np.sqrt((oct1_d5_ta_2 - oct1_d5_0)**2), np.sqrt((oct1_d5_ta_25 - oct1_d5_0)**2)]
# oct1_d6_ta_ch = [0.0, np.sqrt((oct1_d6_ta_05 - oct1_d6_0)**2), np.sqrt((oct1_d6_ta_075 - oct1_d6_0)**2), np.sqrt((oct1_d6_ta_1 - oct1_d6_0)**2), np.sqrt((oct1_d6_ta_15 - oct1_d6_0)**2), np.sqrt((oct1_d6_ta_2 - oct1_d6_0)**2), np.sqrt((oct1_d6_ta_25 - oct1_d6_0)**2)]

oct1_d1_ta_ch = [0.0, ((oct1_d1_ta_05 - oct1_d1_0)), ((oct1_d1_ta_075 - oct1_d1_0)), ((oct1_d1_ta_1 - oct1_d1_0)), ((oct1_d1_ta_15 - oct1_d1_0)), ((oct1_d1_ta_2 - oct1_d1_0)), ((oct1_d1_ta_25 - oct1_d1_0))]
oct1_d2_ta_ch = [0.0, ((oct1_d2_ta_05 - oct1_d2_0)), ((oct1_d2_ta_075 - oct1_d2_0)), ((oct1_d2_ta_1 - oct1_d2_0)), ((oct1_d2_ta_15 - oct1_d2_0)), ((oct1_d2_ta_2 - oct1_d2_0)), ((oct1_d2_ta_25 - oct1_d2_0))]
oct1_d3_ta_ch = [0.0, ((oct1_d3_ta_05 - oct1_d3_0)), ((oct1_d3_ta_075 - oct1_d3_0)), ((oct1_d3_ta_1 - oct1_d3_0)), ((oct1_d3_ta_15 - oct1_d3_0)), ((oct1_d3_ta_2 - oct1_d3_0)), ((oct1_d3_ta_25 - oct1_d3_0))]
oct1_d4_ta_ch = [0.0, ((oct1_d4_ta_05 - oct1_d4_0)), ((oct1_d4_ta_075 - oct1_d4_0)), ((oct1_d4_ta_1 - oct1_d4_0)), ((oct1_d4_ta_15 - oct1_d4_0)), ((oct1_d4_ta_2 - oct1_d4_0)), ((oct1_d4_ta_25 - oct1_d4_0))]
oct1_d5_ta_ch = [0.0, ((oct1_d5_ta_05 - oct1_d5_0)), ((oct1_d5_ta_075 - oct1_d5_0)), ((oct1_d5_ta_1 - oct1_d5_0)), ((oct1_d5_ta_15 - oct1_d5_0)), ((oct1_d5_ta_2 - oct1_d5_0)), ((oct1_d5_ta_25 - oct1_d5_0))]
oct1_d6_ta_ch = [0.0, ((oct1_d6_ta_05 - oct1_d6_0)), ((oct1_d6_ta_075 - oct1_d6_0)), ((oct1_d6_ta_1 - oct1_d6_0)), ((oct1_d6_ta_15 - oct1_d6_0)), ((oct1_d6_ta_2 - oct1_d6_0)), ((oct1_d6_ta_25 - oct1_d6_0))]
ax[0].plot(strain, oct1_d1_ta_ch, '-o', label="d$_1$ under tensile a axis")
ax[0].plot(strain, oct1_d2_ta_ch, '-o', label="d$_2$ under tensile a axis")
ax[0].plot(strain, oct1_d3_ta_ch, '-o', label="d$_3$ under tensile a axis")
ax[0].plot(strain, oct1_d4_ta_ch, '-o', label="d$_4$ under tensile a axis")
ax[0].plot(strain, oct1_d5_ta_ch, '-o', label="d$_5$ under tensile a axis")
ax[0].plot(strain, oct1_d6_ta_ch, '-o', label="d$_6$ under tensile a axis")
ax[0].axis([-0.1, 2.6, -0.05, 0.05])
ax[0].set_ylabel('Change of bonding length (ang)')
ax[0].set_xlabel('Strain')
ax[0].grid(True)
ax[0].set_title("a axis tensile")
ax[0].legend()



oct1_d1_tc_ch = [0.0, ((oct1_d1_tc_05 - oct1_d1_0)), ((oct1_d1_tc_075 - oct1_d1_0)), ((oct1_d1_tc_1 - oct1_d1_0)), ((oct1_d1_tc_15 - oct1_d1_0)), ((oct1_d1_tc_2 - oct1_d1_0)), ((oct1_d1_tc_25 - oct1_d1_0))]
oct1_d2_tc_ch = [0.0, ((oct1_d2_tc_05 - oct1_d2_0)), ((oct1_d2_tc_075 - oct1_d2_0)), ((oct1_d2_tc_1 - oct1_d2_0)), ((oct1_d2_tc_15 - oct1_d2_0)), ((oct1_d2_tc_2 - oct1_d2_0)), ((oct1_d2_tc_25 - oct1_d2_0))]
oct1_d3_tc_ch = [0.0, ((oct1_d3_tc_05 - oct1_d3_0)), ((oct1_d3_tc_075 - oct1_d3_0)), ((oct1_d3_tc_1 - oct1_d3_0)), ((oct1_d3_tc_15 - oct1_d3_0)), ((oct1_d3_tc_2 - oct1_d3_0)), ((oct1_d3_tc_25 - oct1_d3_0))]
oct1_d4_tc_ch = [0.0, ((oct1_d4_tc_05 - oct1_d4_0)), ((oct1_d4_tc_075 - oct1_d4_0)), ((oct1_d4_tc_1 - oct1_d4_0)), ((oct1_d4_tc_15 - oct1_d4_0)), ((oct1_d4_tc_2 - oct1_d4_0)), ((oct1_d4_tc_25 - oct1_d4_0))]
oct1_d5_tc_ch = [0.0, ((oct1_d5_tc_05 - oct1_d5_0)), ((oct1_d5_tc_075 - oct1_d5_0)), ((oct1_d5_tc_1 - oct1_d5_0)), ((oct1_d5_tc_15 - oct1_d5_0)), ((oct1_d5_tc_2 - oct1_d5_0)), ((oct1_d5_tc_25 - oct1_d5_0))]
oct1_d6_tc_ch = [0.0, ((oct1_d6_tc_05 - oct1_d6_0)), ((oct1_d6_tc_075 - oct1_d6_0)), ((oct1_d6_tc_1 - oct1_d6_0)), ((oct1_d6_tc_15 - oct1_d6_0)), ((oct1_d6_tc_2 - oct1_d6_0)), ((oct1_d6_tc_25 - oct1_d6_0))]
ax[1].plot(strain, oct1_d1_tc_ch, '-o', label="d$_1$ under tensile c axis")
ax[1].plot(strain, oct1_d2_tc_ch, '-o', label="d$_2$ under tensile c axis")
ax[1].plot(strain, oct1_d3_tc_ch, '-o', label="d$_3$ under tensile c axis")
ax[1].plot(strain, oct1_d4_tc_ch, '-o', label="d$_4$ under tensile c axis")
ax[1].plot(strain, oct1_d5_tc_ch, '-o', label="d$_5$ under tensile c axis")
ax[1].plot(strain, oct1_d6_tc_ch, '-o', label="d$_6$ under tensile c axis")
ax[1].axis([-0.1, 2.6, -0.05, 0.05])
ax[1].set_ylabel('Change of bonding length (ang)')
ax[1].set_xlabel('Strain')
ax[1].grid(True)
ax[1].set_title("c axis tensile")
ax[1].legend()


oct1_d1_sh_ch = [0.0, ((oct1_d1_sh_05 - oct1_d1_0)), ((oct1_d1_sh_075 - oct1_d1_0)), ((oct1_d1_sh_1 - oct1_d1_0)), ((oct1_d1_sh_15 - oct1_d1_0)), ((oct1_d1_sh_2 - oct1_d1_0)), ((oct1_d1_sh_25 - oct1_d1_0))]
oct1_d2_sh_ch = [0.0, ((oct1_d2_sh_05 - oct1_d2_0)), ((oct1_d2_sh_075 - oct1_d2_0)), ((oct1_d2_sh_1 - oct1_d2_0)), ((oct1_d2_sh_15 - oct1_d2_0)), ((oct1_d2_sh_2 - oct1_d2_0)), ((oct1_d2_sh_25 - oct1_d2_0))]
oct1_d3_sh_ch = [0.0, ((oct1_d3_sh_05 - oct1_d3_0)), ((oct1_d3_sh_075 - oct1_d3_0)), ((oct1_d3_sh_1 - oct1_d3_0)), ((oct1_d3_sh_15 - oct1_d3_0)), ((oct1_d3_sh_2 - oct1_d3_0)), ((oct1_d3_sh_25 - oct1_d3_0))]
oct1_d4_sh_ch = [0.0, ((oct1_d4_sh_05 - oct1_d4_0)), ((oct1_d4_sh_075 - oct1_d4_0)), ((oct1_d4_sh_1 - oct1_d4_0)), ((oct1_d4_sh_15 - oct1_d4_0)), ((oct1_d4_sh_2 - oct1_d4_0)), ((oct1_d4_sh_25 - oct1_d4_0))]
oct1_d5_sh_ch = [0.0, ((oct1_d5_sh_05 - oct1_d5_0)), ((oct1_d5_sh_075 - oct1_d5_0)), ((oct1_d5_sh_1 - oct1_d5_0)), ((oct1_d5_sh_15 - oct1_d5_0)), ((oct1_d5_sh_2 - oct1_d5_0)), ((oct1_d5_sh_25 - oct1_d5_0))]
oct1_d6_sh_ch = [0.0, ((oct1_d6_sh_05 - oct1_d6_0)), ((oct1_d6_sh_075 - oct1_d6_0)), ((oct1_d6_sh_1 - oct1_d6_0)), ((oct1_d6_sh_15 - oct1_d6_0)), ((oct1_d6_sh_2 - oct1_d6_0)), ((oct1_d6_sh_25 - oct1_d6_0))]
ax[2].plot(strain, oct1_d1_sh_ch, '-o', label="d$_1$ under shearing bc axis")
ax[2].plot(strain, oct1_d2_sh_ch, '-o', label="d$_2$ under shearing bc axis")
ax[2].plot(strain, oct1_d3_sh_ch, '-o', label="d$_3$ under shearing bc axis")
ax[2].plot(strain, oct1_d4_sh_ch, '-o', label="d$_4$ under shearing bc axis")
ax[2].plot(strain, oct1_d5_sh_ch, '-o', label="d$_5$ under shearing bc axis")
ax[2].plot(strain, oct1_d6_sh_ch, '-o', label="d$_6$ under shearing bc axis")
ax[2].axis([-0.1, 2.6, -0.05, 0.05])
ax[2].set_ylabel('Change of bonding length (ang)')
ax[2].set_xlabel('Strain')
ax[2].grid(True)
ax[2].set_title("bc shearing")
ax[2].legend()

fig.suptitle("Octahedral 1")
# Out:
# Text(0.5, 0.98, 'Octahedral 1')

# %% [markdown]
# # And Angle

# %%
import numpy as np

fig, ax = plt.subplots(ncols=3, figsize=(20, 12))
fig.dpi = 100
strain = [0.0, 0.5, 0.75, 1.0, 1.5, 2.0, 2.5]
# oct1_d1_ta_ch = [0.0, np.sqrt((oct1_d1_ta_05 - oct1_d1_0)**2), np.sqrt((oct1_d1_ta_075 - oct1_d1_0)**2), np.sqrt((oct1_d1_ta_1 - oct1_d1_0)**2), np.sqrt((oct1_d1_ta_15 - oct1_d1_0)**2), np.sqrt((oct1_d1_ta_2 - oct1_d1_0)**2), np.sqrt((oct1_d1_ta_25 - oct1_d1_0)**2)]
# oct1_d2_ta_ch = [0.0, np.sqrt((oct1_d2_ta_05 - oct1_d2_0)**2), np.sqrt((oct1_d2_ta_075 - oct1_d2_0)**2), np.sqrt((oct1_d2_ta_1 - oct1_d2_0)**2), np.sqrt((oct1_d2_ta_15 - oct1_d2_0)**2), np.sqrt((oct1_d2_ta_2 - oct1_d2_0)**2), np.sqrt((oct1_d2_ta_25 - oct1_d2_0)**2)]
# oct1_d3_ta_ch = [0.0, np.sqrt((oct1_d3_ta_05 - oct1_d3_0)**2), np.sqrt((oct1_d3_ta_075 - oct1_d3_0)**2), np.sqrt((oct1_d3_ta_1 - oct1_d3_0)**2), np.sqrt((oct1_d3_ta_15 - oct1_d3_0)**2), np.sqrt((oct1_d3_ta_2 - oct1_d3_0)**2), np.sqrt((oct1_d3_ta_25 - oct1_d3_0)**2)]
# oct1_d4_ta_ch = [0.0, np.sqrt((oct1_d4_ta_05 - oct1_d4_0)**2), np.sqrt((oct1_d4_ta_075 - oct1_d4_0)**2), np.sqrt((oct1_d4_ta_1 - oct1_d4_0)**2), np.sqrt((oct1_d4_ta_15 - oct1_d4_0)**2), np.sqrt((oct1_d4_ta_2 - oct1_d4_0)**2), np.sqrt((oct1_d4_ta_25 - oct1_d4_0)**2)]
# oct1_d5_ta_ch = [0.0, np.sqrt((oct1_d5_ta_05 - oct1_d5_0)**2), np.sqrt((oct1_d5_ta_075 - oct1_d5_0)**2), np.sqrt((oct1_d5_ta_1 - oct1_d5_0)**2), np.sqrt((oct1_d5_ta_15 - oct1_d5_0)**2), np.sqrt((oct1_d5_ta_2 - oct1_d5_0)**2), np.sqrt((oct1_d5_ta_25 - oct1_d5_0)**2)]
# oct1_d6_ta_ch = [0.0, np.sqrt((oct1_d6_ta_05 - oct1_d6_0)**2), np.sqrt((oct1_d6_ta_075 - oct1_d6_0)**2), np.sqrt((oct1_d6_ta_1 - oct1_d6_0)**2), np.sqrt((oct1_d6_ta_15 - oct1_d6_0)**2), np.sqrt((oct1_d6_ta_2 - oct1_d6_0)**2), np.sqrt((oct1_d6_ta_25 - oct1_d6_0)**2)]

oct1_a1_ta_ch = [0.0, ((80.5848 - oct1_a1_0)), ((80.7090 - oct1_a1_0)), ((80.8345 - oct1_a1_0)), ((81.0880 - oct1_a1_0)), ((81.3444 - oct1_a1_0)), ((81.5962 - oct1_a1_0))]
oct1_a2_ta_ch = [0.0, ((80.2613 - oct1_a2_0)), ((80.2194 - oct1_a2_0)), ((80.1779 - oct1_a2_0)), ((80.0916 - oct1_a2_0)), ((79.9896 - oct1_a2_0)), ((79.8923 - oct1_a2_0))]
oct1_a3_ta_ch = [0.0, ((80.4224 - oct1_a3_0)), ((80.4632 - oct1_a3_0)), ((80.5015 - oct1_a3_0)), ((80.5711 - oct1_a3_0)), ((80.6290 - oct1_a3_0)), ((80.6794 - oct1_a3_0))]
oct1_a4_ta_ch = [0.0, ((99.8504 - oct1_a4_0)), ((100.0261 - oct1_a4_0)), ((100.2009 - oct1_a4_0)), ((100.5404 - oct1_a4_0)), ((100.8686 - oct1_a4_0)), ((101.1969 - oct1_a4_0))]
oct1_a5_ta_ch = [0.0, ((99.3358 - oct1_a5_0)), ((99.2702 - oct1_a5_0)), ((99.2037 - oct1_a5_0)), ((99.0857 - oct1_a5_0)), ((98.9878 - oct1_a5_0)), ((98.8989 - oct1_a5_0))]
oct1_a6_ta_ch = [0.0, ((99.2803 - oct1_a6_0)), ((99.1722 - oct1_a6_0)), ((99.0650 - oct1_a6_0)), ((98.8507 - oct1_a6_0)), ((98.6428 - oct1_a6_0)), ((98.4274 - oct1_a6_0))]
ax[0].plot(strain, oct1_a1_ta_ch, '-o', label="a$_1$ under tensile a axis")
ax[0].plot(strain, oct1_a2_ta_ch, '-o', label="a$_2$ under tensile a axis")
ax[0].plot(strain, oct1_a3_ta_ch, '-o', label="a$_3$ under tensile a axis")
ax[0].plot(strain, oct1_a4_ta_ch, '-o', label="a$_4$ under tensile a axis")
ax[0].plot(strain, oct1_a5_ta_ch, '-o', label="a$_5$ under tensile a axis")
ax[0].plot(strain, oct1_a6_ta_ch, '-o', label="a$_6$ under tensile a axis")
ax[0].axis([-0.1, 2.6, -2.5, 2.5])
ax[0].set_ylabel('Change of bonding angle')
ax[0].set_xlabel('Strain')
ax[0].grid(True)
ax[0].set_title("a axis tensile")
ax[0].legend()



oct1_a1_tc_ch = [0.0, ((80.1228 - oct1_a1_0)), ((80.0139 - oct1_a1_0)), ((79.8968 - oct1_a1_0)), ((79.6726 - oct1_a1_0)), ((79.4337 - oct1_a1_0)), ((79.1843 - oct1_a1_0))]
oct1_a2_tc_ch = [0.0, ((80.1230 - oct1_a2_0)), ((80.0141 - oct1_a2_0)), ((79.8969 - oct1_a2_0)), ((79.6726 - oct1_a2_0)), ((79.4337 - oct1_a2_0)), ((79.1843 - oct1_a2_0))]
oct1_a3_tc_ch = [0.0, ((80.1229 - oct1_a3_0)), ((80.0140 - oct1_a3_0)), ((79.8968 - oct1_a3_0)), ((79.6726 - oct1_a3_0)), ((79.4337 - oct1_a3_0)), ((79.1843 - oct1_a3_0))]
oct1_a4_tc_ch = [0.0, ((99.2829 - oct1_a4_0)), ((99.1816 - oct1_a4_0)), ((99.0900 - oct1_a4_0)), ((98.8981 - oct1_a4_0)), ((98.7206 - oct1_a4_0)), ((98.5576 - oct1_a4_0))]
oct1_a5_tc_ch = [0.0, ((99.2829 - oct1_a5_0)), ((99.1816 - oct1_a5_0)), ((99.0900 - oct1_a5_0)), ((98.8981 - oct1_a5_0)), ((98.7206 - oct1_a5_0)), ((98.5576 - oct1_a5_0))]
oct1_a6_tc_ch = [0.0, ((99.2829 - oct1_a6_0)), ((99.1816 - oct1_a6_0)), ((99.0900 - oct1_a6_0)), ((98.8981 - oct1_a6_0)), ((98.7206 - oct1_a6_0)), ((98.5576 - oct1_a6_0))]
ax[1].plot(strain, oct1_a1_tc_ch, '-o', label="a$_1$ under tensile c axis")
ax[1].plot(strain, oct1_a2_tc_ch, '-o', label="a$_2$ under tensile c axis")
ax[1].plot(strain, oct1_a3_tc_ch, '-o', label="a$_3$ under tensile c axis")
ax[1].plot(strain, oct1_a4_tc_ch, '-o', label="a$_4$ under tensile c axis")
ax[1].plot(strain, oct1_a5_tc_ch, '-o', label="a$_5$ under tensile c axis")
ax[1].plot(strain, oct1_a6_tc_ch, '-o', label="a$_6$ under tensile c axis")
ax[1].axis([-0.1, 2.6, -2.5, 2.5])
ax[1].set_ylabel('Change of bonding angle')
ax[1].set_xlabel('Strain')
ax[1].grid(True)
ax[1].set_title("c axis tensile")
ax[1].legend()


oct1_a1_sh_ch = [0.0, ((80.4853 - oct1_a1_0)), ((80.5600 - oct1_a1_0)), ((80.6325 - oct1_a1_0)), ((80.7762 - oct1_a1_0)), ((80.9106 - oct1_a1_0)), ((81.0434 - oct1_a1_0))]
oct1_a2_sh_ch = [0.0, ((80.3368 - oct1_a2_0)), ((80.3359 - oct1_a2_0)), ((80.3347 - oct1_a2_0)), ((80.3234 - oct1_a2_0)), ((80.3074 - oct1_a2_0)), ((80.2814 - oct1_a2_0))]
oct1_a3_sh_ch = [0.0, ((80.1706 - oct1_a3_0)), ((80.0872 - oct1_a3_0)), ((80.0009 - oct1_a3_0)), ((79.8321 - oct1_a3_0)), ((79.6571 - oct1_a3_0)), ((79.4752 - oct1_a3_0))]
oct1_a4_sh_ch = [0.0, ((99.4949 - oct1_a4_0)), ((99.4975 - oct1_a4_0)), ((99.5042 - oct1_a4_0)), ((99.5146 - oct1_a4_0)), ((99.5364 - oct1_a4_0)), ((99.5629 - oct1_a4_0))]
oct1_a5_sh_ch = [0.0, ((99.5187 - oct1_a5_0)), ((99.5341 - oct1_a5_0)), ((99.5514 - oct1_a5_0)), ((99.5827 - oct1_a5_0)), ((99.6180 - oct1_a5_0)), ((99.6609 - oct1_a5_0))]
oct1_a6_sh_ch = [0.0, ((99.4687 - oct1_a6_0)), ((99.4577 - oct1_a6_0)), ((99.4455 - oct1_a6_0)), ((99.4297 - oct1_a6_0)), ((99.4158 - oct1_a6_0)), ((99.4068 - oct1_a6_0))]
ax[2].plot(strain, oct1_a1_sh_ch, '-o', label="a$_1$ under shearing bc axis")
ax[2].plot(strain, oct1_a2_sh_ch, '-o', label="a$_2$ under shearing bc axis")
ax[2].plot(strain, oct1_a3_sh_ch, '-o', label="a$_3$ under shearing bc axis")
ax[2].plot(strain, oct1_a4_sh_ch, '-o', label="a$_4$ under shearing bc axis")
ax[2].plot(strain, oct1_a5_sh_ch, '-o', label="a$_5$ under shearing bc axis")
ax[2].plot(strain, oct1_a6_sh_ch, '-o', label="a$_6$ under shearing bc axis")
ax[2].axis([-0.1, 2.6, -2.5, 2.5])
ax[2].set_ylabel('Change of bonding angle')
ax[2].set_xlabel('Strain')
ax[2].grid(True)
ax[2].set_title("bc shearing")
ax[2].legend()

fig.suptitle("Octahedral 1")
# Out:
# Text(0.5, 0.98, 'Octahedral 1')

# %%
import numpy as np

fig, ax = plt.subplots(ncols=3, figsize=(20, 12))
fig.dpi = 100
strain = [0.0, 0.5, 0.75, 1.0, 1.5, 2.0, 2.5]
oct2_d1_ta_ch = [0.0, ((oct2_d1_ta_05 - oct2_d1_0)), ((oct2_d1_ta_075 - oct2_d1_0)), ((oct2_d1_ta_1 - oct2_d1_0)), ((oct2_d1_ta_15 - oct2_d1_0)), ((oct2_d1_ta_2 - oct2_d1_0)), ((oct2_d1_ta_25 - oct2_d1_0))]
oct2_d2_ta_ch = [0.0, ((oct2_d2_ta_05 - oct2_d2_0)), ((oct2_d2_ta_075 - oct2_d2_0)), ((oct2_d2_ta_1 - oct2_d2_0)), ((oct2_d2_ta_15 - oct2_d2_0)), ((oct2_d2_ta_2 - oct2_d2_0)), ((oct2_d2_ta_25 - oct2_d2_0))]
oct2_d3_ta_ch = [0.0, ((oct2_d3_ta_05 - oct2_d3_0)), ((oct2_d3_ta_075 - oct2_d3_0)), ((oct2_d3_ta_1 - oct2_d3_0)), ((oct2_d3_ta_15 - oct2_d3_0)), ((oct2_d3_ta_2 - oct2_d3_0)), ((oct2_d3_ta_25 - oct2_d3_0))]
oct2_d4_ta_ch = [0.0, ((oct2_d4_ta_05 - oct2_d4_0)), ((oct2_d4_ta_075 - oct2_d4_0)), ((oct2_d4_ta_1 - oct2_d4_0)), ((oct2_d4_ta_15 - oct2_d4_0)), ((oct2_d4_ta_2 - oct2_d4_0)), ((oct2_d4_ta_25 - oct2_d4_0))]
oct2_d5_ta_ch = [0.0, ((oct2_d5_ta_05 - oct2_d5_0)), ((oct2_d5_ta_075 - oct2_d5_0)), ((oct2_d5_ta_1 - oct2_d5_0)), ((oct2_d5_ta_15 - oct2_d5_0)), ((oct2_d5_ta_2 - oct2_d5_0)), ((oct2_d5_ta_25 - oct2_d5_0))]
oct2_d6_ta_ch = [0.0, ((oct2_d6_ta_05 - oct2_d6_0)), ((oct2_d6_ta_075 - oct2_d6_0)), ((oct2_d6_ta_1 - oct2_d6_0)), ((oct2_d6_ta_15 - oct2_d6_0)), ((oct2_d6_ta_2 - oct2_d6_0)), ((oct2_d6_ta_25 - oct2_d6_0))]
ax[0].plot(strain, oct2_d1_ta_ch, '-o', label="d$_1$ under tensile a axis")
ax[0].plot(strain, oct2_d2_ta_ch, '-o', label="d$_2$ under tensile a axis")
ax[0].plot(strain, oct2_d3_ta_ch, '-o', label="d$_3$ under tensile a axis")
ax[0].plot(strain, oct2_d4_ta_ch, '-o', label="d$_4$ under tensile a axis")
ax[0].plot(strain, oct2_d5_ta_ch, '-o', label="d$_5$ under tensile a axis")
ax[0].plot(strain, oct2_d6_ta_ch, '-o', label="d$_6$ under tensile a axis")
ax[0].axis([-0.1, 2.6, -0.05, 0.05])
ax[0].set_ylabel('Change of bonding length (ang)')
ax[0].set_xlabel('Strain')
ax[0].grid(True)
ax[0].set_title("a axis tensile")
ax[0].legend()



oct2_d1_tc_ch = [0.0, ((oct2_d1_tc_05 - oct2_d1_0)), ((oct2_d1_tc_075 - oct2_d1_0)), ((oct2_d1_tc_1 - oct2_d1_0)), ((oct2_d1_tc_15 - oct2_d1_0)), ((oct2_d1_tc_2 - oct2_d1_0)), ((oct2_d1_tc_25 - oct2_d1_0))]
oct2_d2_tc_ch = [0.0, ((oct2_d2_tc_05 - oct2_d2_0)), ((oct2_d2_tc_075 - oct2_d2_0)), ((oct2_d2_tc_1 - oct2_d2_0)), ((oct2_d2_tc_15 - oct2_d2_0)), ((oct2_d2_tc_2 - oct2_d2_0)), ((oct2_d2_tc_25 - oct2_d2_0))]
oct2_d3_tc_ch = [0.0, ((oct2_d3_tc_05 - oct2_d3_0)), ((oct2_d3_tc_075 - oct2_d3_0)), ((oct2_d3_tc_1 - oct2_d3_0)), ((oct2_d3_tc_15 - oct2_d3_0)), ((oct2_d3_tc_2 - oct2_d3_0)), ((oct2_d3_tc_25 - oct2_d3_0))]
oct2_d4_tc_ch = [0.0, ((oct2_d4_tc_05 - oct2_d4_0)), ((oct2_d4_tc_075 - oct2_d4_0)), ((oct2_d4_tc_1 - oct2_d4_0)), ((oct2_d4_tc_15 - oct2_d4_0)), ((oct2_d4_tc_2 - oct2_d4_0)), ((oct2_d4_tc_25 - oct2_d4_0))]
oct2_d5_tc_ch = [0.0, ((oct2_d5_tc_05 - oct2_d5_0)), ((oct2_d5_tc_075 - oct2_d5_0)), ((oct2_d5_tc_1 - oct2_d5_0)), ((oct2_d5_tc_15 - oct2_d5_0)), ((oct2_d5_tc_2 - oct2_d5_0)), ((oct2_d5_tc_25 - oct2_d5_0))]
oct2_d6_tc_ch = [0.0, ((oct2_d6_tc_05 - oct2_d6_0)), ((oct2_d6_tc_075 - oct2_d6_0)), ((oct2_d6_tc_1 - oct2_d6_0)), ((oct2_d6_tc_15 - oct2_d6_0)), ((oct2_d6_tc_2 - oct2_d6_0)), ((oct2_d6_tc_25 - oct2_d6_0))]
ax[1].plot(strain, oct2_d1_tc_ch, '-o', label="d$_1$ under tensile c axis")
ax[1].plot(strain, oct2_d2_tc_ch, '-o', label="d$_2$ under tensile c axis")
ax[1].plot(strain, oct2_d3_tc_ch, '-o', label="d$_3$ under tensile c axis")
ax[1].plot(strain, oct2_d4_tc_ch, '-o', label="d$_4$ under tensile c axis")
ax[1].plot(strain, oct2_d5_tc_ch, '-o', label="d$_5$ under tensile c axis")
ax[1].plot(strain, oct2_d6_tc_ch, '-o', label="d$_6$ under tensile c axis")
ax[1].axis([-0.1, 2.6, -0.05, 0.05])
ax[1].set_ylabel('Change of bonding length (ang)')
ax[1].set_xlabel('Strain')
ax[1].grid(True)
ax[1].set_title("c axis tensile")
ax[1].legend()


oct2_d1_sh_ch = [0.0, ((oct2_d1_sh_05 - oct2_d1_0)), ((oct2_d1_sh_075 - oct2_d1_0)), ((oct2_d1_sh_1 - oct2_d1_0)), ((oct2_d1_sh_15 - oct2_d1_0)), ((oct2_d1_sh_2 - oct2_d1_0)), ((oct2_d1_sh_25 - oct2_d1_0))]
oct2_d2_sh_ch = [0.0, ((oct2_d2_sh_05 - oct2_d2_0)), ((oct2_d2_sh_075 - oct2_d2_0)), ((oct2_d2_sh_1 - oct2_d2_0)), ((oct2_d2_sh_15 - oct2_d2_0)), ((oct2_d2_sh_2 - oct2_d2_0)), ((oct2_d2_sh_25 - oct2_d2_0))]
oct2_d3_sh_ch = [0.0, ((oct2_d3_sh_05 - oct2_d3_0)), ((oct2_d3_sh_075 - oct2_d3_0)), ((oct2_d3_sh_1 - oct2_d3_0)), ((oct2_d3_sh_15 - oct2_d3_0)), ((oct2_d3_sh_2 - oct2_d3_0)), ((oct2_d3_sh_25 - oct2_d3_0))]
oct2_d4_sh_ch = [0.0, ((oct2_d4_sh_05 - oct2_d4_0)), ((oct2_d4_sh_075 - oct2_d4_0)), ((oct2_d4_sh_1 - oct2_d4_0)), ((oct2_d4_sh_15 - oct2_d4_0)), ((oct2_d4_sh_2 - oct2_d4_0)), ((oct2_d4_sh_25 - oct2_d4_0))]
oct2_d5_sh_ch = [0.0, ((oct2_d5_sh_05 - oct2_d5_0)), ((oct2_d5_sh_075 - oct2_d5_0)), ((oct2_d5_sh_1 - oct2_d5_0)), ((oct2_d5_sh_15 - oct2_d5_0)), ((oct2_d5_sh_2 - oct2_d5_0)), ((oct2_d5_sh_25 - oct2_d5_0))]
oct2_d6_sh_ch = [0.0, ((oct2_d6_sh_05 - oct2_d6_0)), ((oct2_d6_sh_075 - oct2_d6_0)), ((oct2_d6_sh_1 - oct2_d6_0)), ((oct2_d6_sh_15 - oct2_d6_0)), ((oct2_d6_sh_2 - oct2_d6_0)), ((oct2_d6_sh_25 - oct2_d6_0))]
ax[2].plot(strain, oct2_d1_sh_ch, '-o', label="d$_1$ under shearing bc axis")
ax[2].plot(strain, oct2_d2_sh_ch, '-o', label="d$_2$ under shearing bc axis")
ax[2].plot(strain, oct2_d3_sh_ch, '-o', label="d$_3$ under shearing bc axis")
ax[2].plot(strain, oct2_d4_sh_ch, '-o', label="d$_4$ under shearing bc axis")
ax[2].plot(strain, oct2_d5_sh_ch, '-o', label="d$_5$ under shearing bc axis")
ax[2].plot(strain, oct2_d6_sh_ch, '-o', label="d$_6$ under shearing bc axis")
ax[2].axis([-0.1, 2.6, -0.05, 0.05])
ax[2].set_ylabel('Change of bonding length (ang)')
ax[2].set_xlabel('Strain')
ax[2].grid(True)
ax[2].set_title("bc shearing")
ax[2].legend()

fig.suptitle("Octahedral 2")
# Out:
# Text(0.5, 0.98, 'Octahedral 2')

# %%
fig, ax = plt.subplots(ncols=2, figsize=(20, 12))
fig.dpi = 60
strain = [0.0, 0.5, 0.75, 1.0, 1.5, 2.0, 2.5]

ax[0].plot(X1, oct1_zero_strain_1, 'b', label="bulk")
ax[0].plot(X2, oct1_zero_strain_2, 'b')
ax[0].scatter(X, oct1_ta_05, label="tensile 0.5%")
ax[0].scatter(X, oct1_ta_075, label="tensile 0.75%")
ax[0].scatter(X, oct1_ta_1, label="tensile 1.0%")
ax[0].scatter(X, oct1_ta_15, label="tensile 1.5%")
ax[0].scatter(X, oct1_ta_2, label="tensile 2.0%")
ax[0].scatter(X, oct1_ta_25, label="tensile 2.5%")
ax[0].axis([0.9, 6.1, 1.8, 2.2])
ax[0].set_ylabel('Bonding length (ang)')
ax[0].set_xlabel('Bonding index')
ax[0].grid(True)
ax[0].set_title("Octahedral 1")
ax[0].legend()


ax[1].plot(X1, oct2_zero_strain_1, 'b', label="bulk")
ax[1].plot(X2, oct2_zero_strain_2, 'b')
ax[1].scatter(X, oct2_ta_05, label="tensile 0.5%")
ax[1].scatter(X, oct2_ta_075, label="tensile 0.75%")
ax[1].scatter(X, oct2_ta_1, label="tensile 1.0%")
ax[1].scatter(X, oct2_ta_15, label="tensile 1.5%")
ax[1].scatter(X, oct2_ta_2, label="tensile 2.0%")
ax[1].scatter(X, oct2_ta_25, label="tensile 2.5%")
ax[1].axis([0.9, 6.1, 1.8, 2.2])
ax[1].set_ylabel('Bonding length (ang)')
ax[1].set_xlabel('Bonding number')
ax[1].grid(True)
ax[1].set_title("Octahedral 2")
ax[1].legend()

# %% [markdown]
# # Tensile, c axis

# %%
from pymatgen.io.vasp import Poscar
import matplotlib.pyplot as plt

poscar = Poscar.from_file("LNO_strain/POSCAR")
structure = poscar.structure

poscar_tc_05 = Poscar.from_file("LNO_strain/POSCAR_tc_05")
structure_tc_05 = poscar_tc_05.structure

poscar_tc_075 = Poscar.from_file("LNO_strain/POSCAR_tc_075")
structure_tc_075 = poscar_tc_075.structure

poscar_tc_1 = Poscar.from_file("LNO_strain/POSCAR_tc_1")
structure_tc_1 = poscar_tc_1.structure

poscar_tc_15 = Poscar.from_file("LNO_strain/POSCAR_tc_15")
structure_tc_15 = poscar_tc_15.structure

poscar_tc_2 = Poscar.from_file("LNO_strain/POSCAR_tc_2")
structure_tc_2 = poscar_tc_2.structure

poscar_tc_25 = Poscar.from_file("LNO_strain/POSCAR_tc_25")
structure_tc_25 = poscar_tc_25.structure

# def dist(i,j):
#     x = structure.get_distance(i,j)
#     return x
####
X = [1,2,3,4,5,6]
X1 = [1,2,3]
X2 = [4,5,6]
oct1_d6_0 = structure.get_distance(8, 18) ## Unit is angstrom
oct1_d5_0 = structure.get_distance(8, 19) ## Unit is angstrom
oct1_d4_0 = structure.get_distance(8, 20) ## Unit is angstrom
oct1_d3_0 = structure.get_distance(8, 27) ## Unit is angstrom
oct1_d2_0 = structure.get_distance(8, 28) ## Unit is angstrom
oct1_d1_0 = structure.get_distance(8, 29) ## Unit is angstrom

oct2_d2_0 = structure.get_distance(9, 18) ## Unit is angstrom
oct2_d3_0 = structure.get_distance(9, 19) ## Unit is angstrom
oct2_d1_0 = structure.get_distance(9, 20) ## Unit is angstrom
oct2_d5_0 = structure.get_distance(9, 21) ## Unit is angstrom
oct2_d6_0 = structure.get_distance(9, 22) ## Unit is angstrom
oct2_d4_0 = structure.get_distance(9, 23) ## Unit is angstrom

oct1_zero_strain_1 = [oct1_d1_0, oct1_d2_0, oct1_d3_0]
oct1_zero_strain_2 = [oct1_d4_0, oct1_d5_0, oct1_d6_0]
oct2_zero_strain_1 = [oct2_d1_0, oct2_d2_0, oct2_d3_0]
oct2_zero_strain_2 = [oct2_d4_0, oct2_d5_0, oct2_d6_0]

####
####
oct1_d6_tc_05 = structure_tc_05.get_distance(8, 18) ## Unit is angstrom
oct1_d5_tc_05 = structure_tc_05.get_distance(8, 19) ## Unit is angstrom
oct1_d4_tc_05 = structure_tc_05.get_distance(8, 20) ## Unit is angstrom
oct1_d3_tc_05 = structure_tc_05.get_distance(8, 27) ## Unit is angstrom
oct1_d2_tc_05 = structure_tc_05.get_distance(8, 28) ## Unit is angstrom
oct1_d1_tc_05 = structure_tc_05.get_distance(8, 29) ## Unit is angstrom

oct2_d2_tc_05 = structure_tc_05.get_distance(9, 18) ## Unit is angstrom
oct2_d3_tc_05 = structure_tc_05.get_distance(9, 19) ## Unit is angstrom
oct2_d1_tc_05 = structure_tc_05.get_distance(9, 20) ## Unit is angstrom
oct2_d5_tc_05 = structure_tc_05.get_distance(9, 21) ## Unit is angstrom
oct2_d6_tc_05 = structure_tc_05.get_distance(9, 22) ## Unit is angstrom
oct2_d4_tc_05 = structure_tc_05.get_distance(9, 23) ## Unit is angstrom

oct1_tc_05 = [oct1_d1_tc_05, oct1_d2_tc_05, oct1_d3_tc_05, oct1_d4_tc_05, oct1_d5_tc_05, oct1_d6_tc_05]
oct2_tc_05 = [oct2_d1_tc_05, oct2_d2_tc_05, oct2_d3_tc_05, oct2_d4_tc_05, oct2_d5_tc_05, oct2_d6_tc_05]

oct1_d6_tc_075 = structure_tc_075.get_distance(8, 18) ## Unit is angstrom
oct1_d5_tc_075 = structure_tc_075.get_distance(8, 19) ## Unit is angstrom
oct1_d4_tc_075 = structure_tc_075.get_distance(8, 20) ## Unit is angstrom
oct1_d3_tc_075 = structure_tc_075.get_distance(8, 27) ## Unit is angstrom
oct1_d2_tc_075 = structure_tc_075.get_distance(8, 28) ## Unit is angstrom
oct1_d1_tc_075 = structure_tc_075.get_distance(8, 29) ## Unit is angstrom

oct2_d2_tc_075 = structure_tc_075.get_distance(9, 18) ## Unit is angstrom
oct2_d3_tc_075 = structure_tc_075.get_distance(9, 19) ## Unit is angstrom
oct2_d1_tc_075 = structure_tc_075.get_distance(9, 20) ## Unit is angstrom
oct2_d5_tc_075 = structure_tc_075.get_distance(9, 21) ## Unit is angstrom
oct2_d6_tc_075 = structure_tc_075.get_distance(9, 22) ## Unit is angstrom
oct2_d4_tc_075 = structure_tc_075.get_distance(9, 23) ## Unit is angstrom

oct1_tc_075 = [oct1_d1_tc_075, oct1_d2_tc_075, oct1_d3_tc_075, oct1_d4_tc_075, oct1_d5_tc_075, oct1_d6_tc_075]
oct2_tc_075 = [oct2_d1_tc_075, oct2_d2_tc_075, oct2_d3_tc_075, oct2_d4_tc_075, oct2_d5_tc_075, oct2_d6_tc_075]

oct1_d6_tc_1 = structure_tc_1.get_distance(8, 18)  # Unit is angstrom
oct1_d5_tc_1 = structure_tc_1.get_distance(8, 19)  # Unit is angstrom
oct1_d4_tc_1 = structure_tc_1.get_distance(8, 20)  # Unit is angstrom
oct1_d3_tc_1 = structure_tc_1.get_distance(8, 27)  # Unit is angstrom
oct1_d2_tc_1 = structure_tc_1.get_distance(8, 28)  # Unit is angstrom
oct1_d1_tc_1 = structure_tc_1.get_distance(8, 29)  # Unit is angstrom

oct2_d2_tc_1 = structure_tc_1.get_distance(9, 18)  # Unit is angstrom
oct2_d3_tc_1 = structure_tc_1.get_distance(9, 19)  # Unit is angstrom
oct2_d1_tc_1 = structure_tc_1.get_distance(9, 20)  # Unit is angstrom
oct2_d5_tc_1 = structure_tc_1.get_distance(9, 21)  # Unit is angstrom
oct2_d6_tc_1 = structure_tc_1.get_distance(9, 22)  # Unit is angstrom
oct2_d4_tc_1 = structure_tc_1.get_distance(9, 23)  # Unit is angstrom

oct1_tc_1 = [oct1_d1_tc_1, oct1_d2_tc_1, oct1_d3_tc_1, oct1_d4_tc_1, oct1_d5_tc_1, oct1_d6_tc_1]
oct2_tc_1 = [oct2_d1_tc_1, oct2_d2_tc_1, oct2_d3_tc_1, oct2_d4_tc_1, oct2_d5_tc_1, oct2_d6_tc_1]

oct1_d6_tc_15 = structure_tc_15.get_distance(8, 18)  # Unit is angstrom
oct1_d5_tc_15 = structure_tc_15.get_distance(8, 19)  # Unit is angstrom
oct1_d4_tc_15 = structure_tc_15.get_distance(8, 20)  # Unit is angstrom
oct1_d3_tc_15 = structure_tc_15.get_distance(8, 27)  # Unit is angstrom
oct1_d2_tc_15 = structure_tc_15.get_distance(8, 28)  # Unit is angstrom
oct1_d1_tc_15 = structure_tc_15.get_distance(8, 29)  # Unit is angstrom

oct2_d2_tc_15 = structure_tc_15.get_distance(9, 18)  # Unit is angstrom
oct2_d3_tc_15 = structure_tc_15.get_distance(9, 19)  # Unit is angstrom
oct2_d1_tc_15 = structure_tc_15.get_distance(9, 20)  # Unit is angstrom
oct2_d5_tc_15 = structure_tc_15.get_distance(9, 21)  # Unit is angstrom
oct2_d6_tc_15 = structure_tc_15.get_distance(9, 22)  # Unit is angstrom
oct2_d4_tc_15 = structure_tc_15.get_distance(9, 23)  # Unit is angstrom

oct1_tc_15 = [oct1_d1_tc_15, oct1_d2_tc_15, oct1_d3_tc_15, oct1_d4_tc_15, oct1_d5_tc_15, oct1_d6_tc_15]
oct2_tc_15 = [oct2_d1_tc_15, oct2_d2_tc_15, oct2_d3_tc_15, oct2_d4_tc_15, oct2_d5_tc_15, oct2_d6_tc_15]

oct1_d6_tc_2 = structure_tc_2.get_distance(8, 18)  # Unit is angstrom
oct1_d5_tc_2 = structure_tc_2.get_distance(8, 19)  # Unit is angstrom
oct1_d4_tc_2 = structure_tc_2.get_distance(8, 20)  # Unit is angstrom
oct1_d3_tc_2 = structure_tc_2.get_distance(8, 27)  # Unit is angstrom
oct1_d2_tc_2 = structure_tc_2.get_distance(8, 28)  # Unit is angstrom
oct1_d1_tc_2 = structure_tc_2.get_distance(8, 29)  # Unit is angstrom

oct2_d2_tc_2 = structure_tc_2.get_distance(9, 18)  # Unit is angstrom
oct2_d3_tc_2 = structure_tc_2.get_distance(9, 19)  # Unit is angstrom
oct2_d1_tc_2 = structure_tc_2.get_distance(9, 20)  # Unit is angstrom
oct2_d5_tc_2 = structure_tc_2.get_distance(9, 21)  # Unit is angstrom
oct2_d6_tc_2 = structure_tc_2.get_distance(9, 22)  # Unit is angstrom
oct2_d4_tc_2 = structure_tc_2.get_distance(9, 23)  # Unit is angstrom

oct1_tc_2 = [oct1_d1_tc_2, oct1_d2_tc_2, oct1_d3_tc_2, oct1_d4_tc_2, oct1_d5_tc_2, oct1_d6_tc_2]
oct2_tc_2 = [oct2_d1_tc_2, oct2_d2_tc_2, oct2_d3_tc_2, oct2_d4_tc_2, oct2_d5_tc_2, oct2_d6_tc_2]

oct1_d6_tc_25 = structure_tc_25.get_distance(8, 18)  # Unit is angstrom
oct1_d5_tc_25 = structure_tc_25.get_distance(8, 19)  # Unit is angstrom
oct1_d4_tc_25 = structure_tc_25.get_distance(8, 20)  # Unit is angstrom
oct1_d3_tc_25 = structure_tc_25.get_distance(8, 27)  # Unit is angstrom
oct1_d2_tc_25 = structure_tc_25.get_distance(8, 28)  # Unit is angstrom
oct1_d1_tc_25 = structure_tc_25.get_distance(8, 29)  # Unit is angstrom

oct2_d2_tc_25 = structure_tc_25.get_distance(9, 18)  # Unit is angstrom
oct2_d3_tc_25 = structure_tc_25.get_distance(9, 19)  # Unit is angstrom
oct2_d1_tc_25 = structure_tc_25.get_distance(9, 20)  # Unit is angstrom
oct2_d5_tc_25 = structure_tc_25.get_distance(9, 21)  # Unit is angstrom
oct2_d6_tc_25 = structure_tc_25.get_distance(9, 22)  # Unit is angstrom
oct2_d4_tc_25 = structure_tc_25.get_distance(9, 23)  # Unit is angstrom

oct1_tc_25 = [oct1_d1_tc_25, oct1_d2_tc_25, oct1_d3_tc_25, oct1_d4_tc_25, oct1_d5_tc_25, oct1_d6_tc_25]
oct2_tc_25 = [oct2_d1_tc_25, oct2_d2_tc_25, oct2_d3_tc_25, oct2_d4_tc_25, oct2_d5_tc_25, oct2_d6_tc_25]

# %%
fig, ax = plt.subplots(ncols=2, figsize=(20, 12))
fig.dpi = 180
ax[0].plot(X1, oct1_zero_strain_1, 'b', label="bulk")
ax[0].plot(X2, oct1_zero_strain_2, 'b')
ax[0].scatter(X, oct1_tc_05, label="tensile 0.5%")
ax[0].scatter(X, oct1_tc_075, label="tensile 0.75%")
ax[0].scatter(X, oct1_tc_1, label="tensile 1.0%")
ax[0].scatter(X, oct1_tc_15, label="tensile 1.5%")
ax[0].scatter(X, oct1_tc_2, label="tensile 2.0%")
ax[0].scatter(X, oct1_tc_25, label="tensile 2.5%")

ax[0].axis([0.9, 6.1, 1.8, 2.2])
ax[0].set_ylabel('Bonding length (ang)')
ax[0].set_xlabel('Bonding number')
ax[0].grid(True)
ax[0].set_title("Octahedral 1")
ax[0].legend()

ax[1].plot(X1, oct2_zero_strain_1, 'b', label="bulk")
ax[1].plot(X2, oct2_zero_strain_2, 'b')
ax[1].scatter(X, oct2_tc_05, label="tensile 0.5%")
ax[1].scatter(X, oct2_tc_075, label="tensile 0.75%")
ax[1].scatter(X, oct2_tc_1, label="tensile 1.0%")
ax[1].scatter(X, oct2_tc_15, label="tensile 1.5%")
ax[1].scatter(X, oct2_tc_2, label="tensile 2.0%")
ax[1].scatter(X, oct2_tc_25, label="tensile 2.5%")
ax[1].axis([0.9, 6.1, 1.8, 2.2])
ax[1].set_ylabel('Bonding length (ang)')
ax[1].set_xlabel('Bonding number')
ax[1].grid(True)
ax[1].set_title("Octahedral 2")
ax[1].legend()

# %% [markdown]
# # Shearing

# %%
from pymatgen.io.vasp import Poscar
import matplotlib.pyplot as plt

poscar = Poscar.from_file("LNO_strain/POSCAR")
structure = poscar.structure

poscar_sh_05 = Poscar.from_file("LNO_strain/POSCAR_sh_05")
structure_sh_05 = poscar_sh_05.structure

poscar_sh_075 = Poscar.from_file("LNO_strain/POSCAR_sh_075")
structure_sh_075 = poscar_sh_075.structure

poscar_sh_1 = Poscar.from_file("LNO_strain/POSCAR_sh_1")
structure_sh_1 = poscar_sh_1.structure

poscar_sh_15 = Poscar.from_file("LNO_strain/POSCAR_sh_15")
structure_sh_15 = poscar_sh_15.structure

poscar_sh_2 = Poscar.from_file("LNO_strain/POSCAR_sh_2")
structure_sh_2 = poscar_sh_2.structure

poscar_sh_25 = Poscar.from_file("LNO_strain/POSCAR_sh_25")
structure_sh_25 = poscar_sh_25.structure

# def dist(i,j):
#     x = structure.get_distance(i,j)
#     return x
####
X = [1,2,3,4,5,6]
X1 = [1,2,3]
X2 = [4,5,6]
oct1_d6_0 = structure.get_distance(8, 18) ## Unit is angstrom
oct1_d5_0 = structure.get_distance(8, 19) ## Unit is angstrom
oct1_d4_0 = structure.get_distance(8, 20) ## Unit is angstrom
oct1_d3_0 = structure.get_distance(8, 27) ## Unit is angstrom
oct1_d2_0 = structure.get_distance(8, 28) ## Unit is angstrom
oct1_d1_0 = structure.get_distance(8, 29) ## Unit is angstrom

oct2_d2_0 = structure.get_distance(9, 18) ## Unit is angstrom
oct2_d3_0 = structure.get_distance(9, 19) ## Unit is angstrom
oct2_d1_0 = structure.get_distance(9, 20) ## Unit is angstrom
oct2_d5_0 = structure.get_distance(9, 21) ## Unit is angstrom
oct2_d6_0 = structure.get_distance(9, 22) ## Unit is angstrom
oct2_d4_0 = structure.get_distance(9, 23) ## Unit is angstrom

oct1_zero_strain_1 = [oct1_d1_0, oct1_d2_0, oct1_d3_0]
oct1_zero_strain_2 = [oct1_d4_0, oct1_d5_0, oct1_d6_0]
oct2_zero_strain_1 = [oct2_d1_0, oct2_d2_0, oct2_d3_0]
oct2_zero_strain_2 = [oct2_d4_0, oct2_d5_0, oct2_d6_0]

oct1_d6_sh_05 = structure_sh_05.get_distance(8, 18) ## Unit is angstrom
oct1_d5_sh_05 = structure_sh_05.get_distance(8, 19) ## Unit is angstrom
oct1_d4_sh_05 = structure_sh_05.get_distance(8, 20) ## Unit is angstrom
oct1_d3_sh_05 = structure_sh_05.get_distance(8, 27) ## Unit is angstrom
oct1_d2_sh_05 = structure_sh_05.get_distance(8, 28) ## Unit is angstrom
oct1_d1_sh_05 = structure_sh_05.get_distance(8, 29) ## Unit is angstrom

oct2_d2_sh_05 = structure_sh_05.get_distance(9, 18) ## Unit is angstrom
oct2_d3_sh_05 = structure_sh_05.get_distance(9, 19) ## Unit is angstrom
oct2_d1_sh_05 = structure_sh_05.get_distance(9, 20) ## Unit is angstrom
oct2_d5_sh_05 = structure_sh_05.get_distance(9, 21) ## Unit is angstrom
oct2_d6_sh_05 = structure_sh_05.get_distance(9, 22) ## Unit is angstrom
oct2_d4_sh_05 = structure_sh_05.get_distance(9, 23) ## Unit is angstrom

oct1_sh_05 = [oct1_d1_sh_05, oct1_d2_sh_05, oct1_d3_sh_05, oct1_d4_sh_05, oct1_d5_sh_05, oct1_d6_sh_05]
oct2_sh_05 = [oct2_d1_sh_05, oct2_d2_sh_05, oct2_d3_sh_05, oct2_d4_sh_05, oct2_d5_sh_05, oct2_d6_sh_05]

oct1_d6_sh_075 = structure_sh_075.get_distance(8, 18) ## Unit is angstrom
oct1_d5_sh_075 = structure_sh_075.get_distance(8, 19) ## Unit is angstrom
oct1_d4_sh_075 = structure_sh_075.get_distance(8, 20) ## Unit is angstrom
oct1_d3_sh_075 = structure_sh_075.get_distance(8, 27) ## Unit is angstrom
oct1_d2_sh_075 = structure_sh_075.get_distance(8, 28) ## Unit is angstrom
oct1_d1_sh_075 = structure_sh_075.get_distance(8, 29) ## Unit is angstrom

oct2_d2_sh_075 = structure_sh_075.get_distance(9, 18) ## Unit is angstrom
oct2_d3_sh_075 = structure_sh_075.get_distance(9, 19) ## Unit is angstrom
oct2_d1_sh_075 = structure_sh_075.get_distance(9, 20) ## Unit is angstrom
oct2_d5_sh_075 = structure_sh_075.get_distance(9, 21) ## Unit is angstrom
oct2_d6_sh_075 = structure_sh_075.get_distance(9, 22) ## Unit is angstrom
oct2_d4_sh_075 = structure_sh_075.get_distance(9, 23) ## Unit is angstrom

oct1_sh_075 = [oct1_d1_sh_075, oct1_d2_sh_075, oct1_d3_sh_075, oct1_d4_sh_075, oct1_d5_sh_075, oct1_d6_sh_075]
oct2_sh_075 = [oct2_d1_sh_075, oct2_d2_sh_075, oct2_d3_sh_075, oct2_d4_sh_075, oct2_d5_sh_075, oct2_d6_sh_075]

oct1_d6_sh_1 = structure_sh_1.get_distance(8, 18)  # Unit is angstrom
oct1_d5_sh_1 = structure_sh_1.get_distance(8, 19)  # Unit is angstrom
oct1_d4_sh_1 = structure_sh_1.get_distance(8, 20)  # Unit is angstrom
oct1_d3_sh_1 = structure_sh_1.get_distance(8, 27)  # Unit is angstrom
oct1_d2_sh_1 = structure_sh_1.get_distance(8, 28)  # Unit is angstrom
oct1_d1_sh_1 = structure_sh_1.get_distance(8, 29)  # Unit is angstrom

oct2_d2_sh_1 = structure_sh_1.get_distance(9, 18)  # Unit is angstrom
oct2_d3_sh_1 = structure_sh_1.get_distance(9, 19)  # Unit is angstrom
oct2_d1_sh_1 = structure_sh_1.get_distance(9, 20)  # Unit is angstrom
oct2_d5_sh_1 = structure_sh_1.get_distance(9, 21)  # Unit is angstrom
oct2_d6_sh_1 = structure_sh_1.get_distance(9, 22)  # Unit is angstrom
oct2_d4_sh_1 = structure_sh_1.get_distance(9, 23)  # Unit is angstrom

oct1_sh_1 = [oct1_d1_sh_1, oct1_d2_sh_1, oct1_d3_sh_1, oct1_d4_sh_1, oct1_d5_sh_1, oct1_d6_sh_1]
oct2_sh_1 = [oct2_d1_sh_1, oct2_d2_sh_1, oct2_d3_sh_1, oct2_d4_sh_1, oct2_d5_sh_1, oct2_d6_sh_1]

oct1_d6_sh_15 = structure_sh_15.get_distance(8, 18)  # Unit is angstrom
oct1_d5_sh_15 = structure_sh_15.get_distance(8, 19)  # Unit is angstrom
oct1_d4_sh_15 = structure_sh_15.get_distance(8, 20)  # Unit is angstrom
oct1_d3_sh_15 = structure_sh_15.get_distance(8, 27)  # Unit is angstrom
oct1_d2_sh_15 = structure_sh_15.get_distance(8, 28)  # Unit is angstrom
oct1_d1_sh_15 = structure_sh_15.get_distance(8, 29)  # Unit is angstrom

oct2_d2_sh_15 = structure_sh_15.get_distance(9, 18)  # Unit is angstrom
oct2_d3_sh_15 = structure_sh_15.get_distance(9, 19)  # Unit is angstrom
oct2_d1_sh_15 = structure_sh_15.get_distance(9, 20)  # Unit is angstrom
oct2_d5_sh_15 = structure_sh_15.get_distance(9, 21)  # Unit is angstrom
oct2_d6_sh_15 = structure_sh_15.get_distance(9, 22)  # Unit is angstrom
oct2_d4_sh_15 = structure_sh_15.get_distance(9, 23)  # Unit is angstrom

oct1_sh_15 = [oct1_d1_sh_15, oct1_d2_sh_15, oct1_d3_sh_15, oct1_d4_sh_15, oct1_d5_sh_15, oct1_d6_sh_15]
oct2_sh_15 = [oct2_d1_sh_15, oct2_d2_sh_15, oct2_d3_sh_15, oct2_d4_sh_15, oct2_d5_sh_15, oct2_d6_sh_15]

oct1_d6_sh_2 = structure_sh_2.get_distance(8, 18)  # Unit is angstrom
oct1_d5_sh_2 = structure_sh_2.get_distance(8, 19)  # Unit is angstrom
oct1_d4_sh_2 = structure_sh_2.get_distance(8, 20)  # Unit is angstrom
oct1_d3_sh_2 = structure_sh_2.get_distance(8, 27)  # Unit is angstrom
oct1_d2_sh_2 = structure_sh_2.get_distance(8, 28)  # Unit is angstrom
oct1_d1_sh_2 = structure_sh_2.get_distance(8, 29)  # Unit is angstrom

oct2_d2_sh_2 = structure_sh_2.get_distance(9, 18)  # Unit is angstrom
oct2_d3_sh_2 = structure_sh_2.get_distance(9, 19)  # Unit is angstrom
oct2_d1_sh_2 = structure_sh_2.get_distance(9, 20)  # Unit is angstrom
oct2_d5_sh_2 = structure_sh_2.get_distance(9, 21)  # Unit is angstrom
oct2_d6_sh_2 = structure_sh_2.get_distance(9, 22)  # Unit is angstrom
oct2_d4_sh_2 = structure_sh_2.get_distance(9, 23)  # Unit is angstrom

oct1_sh_2 = [oct1_d1_sh_2, oct1_d2_sh_2, oct1_d3_sh_2, oct1_d4_sh_2, oct1_d5_sh_2, oct1_d6_sh_2]
oct2_sh_2 = [oct2_d1_sh_2, oct2_d2_sh_2, oct2_d3_sh_2, oct2_d4_sh_2, oct2_d5_sh_2, oct2_d6_sh_2]

oct1_d6_sh_25 = structure_sh_25.get_distance(8, 18)  # Unit is angstrom
oct1_d5_sh_25 = structure_sh_25.get_distance(8, 19)  # Unit is angstrom
oct1_d4_sh_25 = structure_sh_25.get_distance(8, 20)  # Unit is angstrom
oct1_d3_sh_25 = structure_sh_25.get_distance(8, 27)  # Unit is angstrom
oct1_d2_sh_25 = structure_sh_25.get_distance(8, 28)  # Unit is angstrom
oct1_d1_sh_25 = structure_sh_25.get_distance(8, 29)  # Unit is angstrom

oct2_d2_sh_25 = structure_sh_25.get_distance(9, 18)  # Unit is angstrom
oct2_d3_sh_25 = structure_sh_25.get_distance(9, 19)  # Unit is angstrom
oct2_d1_sh_25 = structure_sh_25.get_distance(9, 20)  # Unit is angstrom
oct2_d5_sh_25 = structure_sh_25.get_distance(9, 21)  # Unit is angstrom
oct2_d6_sh_25 = structure_sh_25.get_distance(9, 22)  # Unit is angstrom
oct2_d4_sh_25 = structure_sh_25.get_distance(9, 23)  # Unit is angstrom

oct1_sh_25 = [oct1_d1_sh_25, oct1_d2_sh_25, oct1_d3_sh_25, oct1_d4_sh_25, oct1_d5_sh_25, oct1_d6_sh_25]
oct2_sh_25 = [oct2_d1_sh_25, oct2_d2_sh_25, oct2_d3_sh_25, oct2_d4_sh_25, oct2_d5_sh_25, oct2_d6_sh_25]

# %%
fig, ax = plt.subplots(ncols=2, figsize=(20, 12))
fig.dpi = 180
ax[0].plot(X1, oct1_zero_strain_1, 'b', label="bulk")
ax[0].plot(X2, oct1_zero_strain_2, 'b')
ax[0].scatter(X, oct1_sh_05, label="shearing 0.5%")
ax[0].scatter(X, oct1_sh_075, label="shearing 0.75%")
ax[0].scatter(X, oct1_sh_1, label="shearing 1.0%")
ax[0].scatter(X, oct1_sh_15, label="shearing 1.5%")
ax[0].scatter(X, oct1_sh_2, label="shearing 2.0%")
ax[0].scatter(X, oct1_sh_25, label="shearing 2.5%")

ax[0].axis([0.9, 6.1, 1.8, 2.2])
ax[0].set_ylabel('Bonding length (ang)')
ax[0].set_xlabel('Bonding number')
ax[0].grid(True)
ax[0].set_title("Octahedral 1")
ax[0].legend()

ax[1].plot(X1, oct2_zero_strain_1, 'b', label="bulk")
ax[1].plot(X2, oct2_zero_strain_2, 'b')
ax[1].scatter(X, oct2_sh_05, label="shearing 0.5%")
ax[1].scatter(X, oct2_sh_075, label="shearing 0.75%")
ax[1].scatter(X, oct2_sh_1, label="shearing 1.0%")
ax[1].scatter(X, oct2_sh_15, label="shearing 1.5%")
ax[1].scatter(X, oct2_sh_2, label="shearing 2.0%")
ax[1].scatter(X, oct2_sh_25, label="shearing 2.5%")
ax[1].axis([0.9, 6.1, 1.8, 2.2])
ax[1].set_ylabel('Bonding length (ang)')
ax[1].set_xlabel('Bonding number')
ax[1].grid(True)
ax[1].set_title("Octahedral 2")
ax[1].legend()

# %%
from pymatgen.io.vasp import Poscar
import numpy as np

"""

Plotting bonding length in PE, AFE, and FE lithium niobate.

"""

file_name = "VASP_files/POSCAR_LNO_FE"
# file_name = "VASP_files/POSCAR_PBEsol"
poscar = Poscar.from_file(file_name)
struc = poscar.structure
print(struc)
bonding_length = [struc.get_distance(2,4), struc.get_distance(2,5), struc.get_distance(2,6), struc.get_distance(2,7), struc.get_distance(2,8), struc.get_distance(2,9)]
print(bonding_length)
# Out:
# Full Formula (Li2 Nb2 O6)
# Reduced Formula: LiNbO3
# abc   :   5.449088   5.449088   5.449088
# angles:  56.661942  56.661942  56.661942
# pbc   :       True       True       True
# Sites (10)
#   #  SP           a         b         c  velocities
# ---  ----  --------  --------  --------  ---------------
#   0  Li    0.289925  0.289925  0.289925  [0.0, 0.0, 0.0]
#   1  Li    0.789925  0.789925  0.789925  [0.0, 0.0, 0.0]
#   2  Nb    0.507961  0.507961  0.507961  [0.0, 0.0, 0.0]
#   3  Nb    0.007961  0.007961  0.007961  [0.0, 0.0, 0.0]
#   4  O     0.118461  0.373437  0.727217  [0.0, 0.0, 0.0]
#   5  O     0.373437  0.727217  0.118461  [0.0, 0.0, 0.0]
#   6  O     0.873437  0.618461  0.227217  [0.0, 0.0, 0.0]
#   7  O     0.227217  0.873437  0.618461  [0.0, 0.0, 0.0]
#   8  O     0.618461  0.227217  0.873437  [0.0, 0.0, 0.0]
#   9  O     0.727217  0.118461  0.373437  [0.0, 0.0, 0.0]
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=3, figsize=(25, 12))
fig.dpi = 100
mode = ["Li1_x", "Li1_y", "Li1_z", "Li2_x", "Li2_Y", "Li2_z", "Nb1_x", "Nb1_y", "Nb1_z", "Nb2_x", "Nb2_y", "Nb2_z", "O1_x", "O1_y", "O1_z", "O2_x", "O2_y", "O2_z", "O3_x", "O3_y", "O3_z", "O4_x", "O4_y", "O4_z", "O5_x", "O5_y", "O5_z", "O6_x", "O6_y", "O6_z"]



ax[0].bar(mode, max_dchi_dtau_PE_forward)
ax[0].axis([-0.5, 30, 0, 5.5])
# ax[0].set_ylabel('Maximum component of the change of dielectric tensor')
# ax[0].set_xlabel('mode')
ax[0].grid(True)
ax[0].set_title("0.01 Ang displacement")
ax[0].legend()
ax[0].set_xticks(mode)

ax[1].bar(mode, max_dchi_dtau_PE_forward_005)
ax[1].axis([-0.5, 30, 0, 5.5])
# ax[1].set_ylabel('Maximum component of the change of dielectric tensor')
# ax[1].set_xlabel('mode')
ax[1].grid(True)
ax[1].set_title("0.05 Ang displacement")
ax[1].legend()
ax[1].set_xticks(mode)


ax[2].bar(mode, max_dchi_dtau_PE_forward_01)
ax[2].axis([-0.5, 30, 0, 5.5])
# ax[2].set_ylabel('Maximum component of the change of dielectric tensor')
# ax[2].set_xlabel('mode')
ax[2].grid(True)
ax[2].set_title("0.1 Ang displacement")
ax[2].legend()
ax[2].set_xticks(mode)


fig.suptitle("The change of susceptibility with 0.01, 0.05, and 0.1 Ang")
