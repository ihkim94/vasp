# %% [markdown]
# # Exercise 1
#
# Repeat the calculations with the different values of ecutwfc.

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(ncols=2, figsize=(20, 12))
fig.dpi = 100


xx = np.array([5, 10, 15, 20, 25, 30, 35, 40, 50, 100, 200, 300, 400])
energy = [-15.60437791, -15.77558471, -15.83422239, -15.84721984, -15.85087566, -15.85182959, -15.85235146, -15.85268612, -15.85300082, -15.85306908, -15.85306929, -15.85306782, -15.85306925]
ax[0].plot(xx, energy, 'bs-', markersize=8)
ax[0].axis([0, 405, -15.9, -15.6])
ax[0].set_ylabel('Total energy (Ry)', fontsize=18)
ax[0].set_xlabel('ecutwfc (Ry)',fontsize=18)
ax[0].xaxis.set_tick_params(labelsize=14)
ax[0].yaxis.set_tick_params(labelsize=14)
ax[0].grid(True)
# ax[0].set_title("Paraelectric phase")
ax[0].legend()
# ax[0].set_xticks(xx)

ax[1].plot(xx, energy, 'bs-', markersize=8)
ax[1].axis([0, 40, -15.9, -15.6])
ax[1].set_ylabel('Total energy (Ry)', fontsize=18)
ax[1].set_xlabel('ecutwfc (Ry)', fontsize=18)
ax[1].xaxis.set_tick_params(labelsize=14)
ax[1].yaxis.set_tick_params(labelsize=14)
ax[1].grid(True)
# ax[0].set_title("Paraelectric phase")
ax[1].legend()
# ax[0].set_xticks(xx)

fig.savefig("Excercis1_1")
# fig.suptitle("")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(ncols=2, figsize=(20, 12))
fig.dpi = 100
x = np.linspace(0, 2, 10000)


xx = np.array([5, 10, 15, 20, 25, 30, 35, 40, 50, 100, 200, 300, 400])
yy = [0.27, 0.73, 0.94, 0.32, 0.81, 0.41, 0.97, 1.14, 0.92, 0.31, 1.2, 1.52, 1.77]
ax[0].plot(xx, yy, 'bs-', markersize=8)
ax[0].set_ylabel('CPU time (s)', fontsize=18)
ax[0].set_xlabel('ecutwfc (Ry)',fontsize=18)
ax[0].xaxis.set_tick_params(labelsize=14)
ax[0].yaxis.set_tick_params(labelsize=14)
ax[0].grid(True)
# ax[0].set_title("Paraelectric phase")
ax[0].legend()
# ax[0].set_xticks(xx)

ax[1].plot(xx, yy, 'bs-', markersize=8)
ax[1].axis([0, 40, 0, 2])
ax[1].set_ylabel('CPU time (s)', fontsize=18)
ax[1].set_xlabel('ecutwfc (Ry)', fontsize=18)
ax[1].xaxis.set_tick_params(labelsize=14)
ax[1].yaxis.set_tick_params(labelsize=14)
ax[1].grid(True)
# ax[0].set_title("Paraelectric phase")
ax[1].legend()
# ax[0].set_xticks(xx)

fig.savefig("Excercis1_2")
# fig.suptitle("")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(ncols=2, figsize=(20, 12))
fig.dpi = 100
x = np.linspace(0, 8000, 1000000)

xx = np.array([5, 10, 15, 20, 25, 30, 35, 40, 50, 100, 200, 300, 400])
yy = [137, 283, 459, 645, 893, 1139, 1363, 1639, 2229, 5769, 15089, 27221, 40857]


ax[0].plot(xx, yy, 'bs-', markersize=8)
# ax[0].axis([0, 405, 0, 2])
ax[0].set_ylabel('Number of planewaves', fontsize=18)
ax[0].set_xlabel('ecutwfc (Ry)',fontsize=18)
ax[0].xaxis.set_tick_params(labelsize=14)
ax[0].yaxis.set_tick_params(labelsize=14)
ax[0].grid(True)
# ax[0].set_title("Paraelectric phase")
ax[0].legend()
# ax[0].set_xticks(xx)

def rel(x):
    return x**(3/2)

ax[1].plot(rel(xx), yy, 'bs-', markersize=8)
# ax[1].plot(x, rel(x))
# ax[1].axis([0, 1000, 0, 10000])
ax[1].set_ylabel('CPU time (s)', fontsize=18)
ax[1].set_xlabel('ecutwfc $^{3/2}$ (Ry)', fontsize=18)
ax[1].xaxis.set_tick_params(labelsize=14)
ax[1].yaxis.set_tick_params(labelsize=14)
ax[1].grid(True)
# ax[0].set_title("Paraelectric phase")
ax[1].legend()
# ax[0].set_xticks(xx)

fig.savefig("Excercis1_3")
# fig.suptitle("")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(ncols=2, figsize=(20, 12))
fig.dpi = 100


xx = np.array(["1x1x1", "2x2x2", "4x4x4", "8x8x8", "16x16x16", "32x32x32"])
energy = [-14.59239647, -15.66198439, -15.83707528, -15.85079063, -15.85108166, -15.85108141]
ax[0].plot(xx, energy, 'bs-', markersize=8)
# ax[0].axis([0, 405, -15.9, -15.6])
ax[0].set_ylabel('Total energy (Ry)', fontsize=18)
ax[0].set_xlabel('k-point',fontsize=18)
ax[0].xaxis.set_tick_params(labelsize=14)
ax[0].yaxis.set_tick_params(labelsize=14)
ax[0].grid(True)
# ax[0].set_title("Paraelectric phase")
ax[0].legend()
# ax[0].set_xticks(xx)

xx2 = [1, 3, 8, 29, 145, 897] 
ax[1].plot(xx2, energy, 'bs-', markersize=8)
# ax[1].axis([-50, 5000, -15.9, -14.5])
ax[1].set_ylabel('Total energy (Ry)', fontsize=18)
ax[1].set_xlabel('number of k-points', fontsize=18)
ax[1].xaxis.set_tick_params(labelsize=14)
ax[1].yaxis.set_tick_params(labelsize=14)
ax[1].grid(True)
# ax[0].set_title("Paraelectric phase")
ax[1].legend()
# ax[0].set_xticks(xx)

fig.savefig("Excercis2_1")
# fig.suptitle("")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy as np
import matplotlib.pyplot as plt

xx = [1, 3, 8, 29, 145, 897] 
xx2 = [1, 2, 10, 60, 408, 2992]
energy_unshifted = [-14.59239647, -15.66198439, -15.83707528, -15.85079063, -15.85108166, -15.85108141]
energy_shifted = [-15.66368652, -15.83894670, -15.85087566, -15.85108290, -15.85108128, -15.85108150]

plt.figure()
plt.plot(xx, energy_unshifted, 'bs-', markersize=8)
plt.plot(xx2, energy_shifted, 'rs-', markersize=8)
plt.rcParams['figure.dpi'] = 400
plt.xscale("log")
plt.ylabel('Total energy (Ry)', fontsize=14)
plt.xlabel('number of k-points',fontsize=14)
# plt.xaxis.set_tick_params(labelsize=14)
# plt.yaxis.set_tick_params(labelsize=14)
plt.grid(True)
# ax[0].set_title("Paraelectric phase")
plt.legend(['unshifted', 'shifted'])
# ax[0].set_xticks(xx)
plt.savefig("Excercis2_2")

# %%
import numpy as np
import matplotlib.pyplot as plt

xx = [1, 2, 3, 8, 10, 29, 60, 145, 408, 897, 2992] 
xx2 = [1, 2, 10, 60, 408, 2992]
time_unshifted = [0.05, 0.05, 0.05, 0.08, 0.22, 0.22, 0.27, 0.99, 2.88, 5.92, 19.42]

plt.figure()
plt.plot(xx, time_unshifted, 'bs-', markersize=8)
plt.rcParams['figure.dpi'] = 400
plt.ylabel('Time spent on calculation (s)', fontsize=14)
plt.xlabel('number of k-points',fontsize=14)
# plt.xaxis.set_tick_params(labelsize=14)
# plt.yaxis.set_tick_params(labelsize=14)
plt.grid(True)
# ax[0].set_title("Paraelectric phase")
# plt.legend(['unshifted', 'shifted'])
# ax[0].set_xticks(xx)
plt.savefig("Excercis2_3")

# %%
import numpy as np
import matplotlib.pyplot as plt

def rel(x):
    return x**3
xx = np.array([2, 16, 54, 128, 250, 432])
time = [0.04, 1.34, 3.02, 16.29, 83.29, 334.34]

fig, ax = plt.subplots(ncols=2, figsize=(20, 12))
fig.dpi = 100


ax[0].plot(xx, time, 'bs-', markersize=8)
# ax[0].axis([0, 405, -15.9, -15.6])
ax[0].set_ylabel('Time spent on calculation (s)', fontsize=18)
ax[0].set_xlabel('number of atoms', fontsize=18)
ax[0].xaxis.set_tick_params(labelsize=14)
ax[0].yaxis.set_tick_params(labelsize=14)
ax[0].grid(True)
# ax[0].set_title("Paraelectric phase")
ax[0].legend()
# ax[0].set_xticks(xx)

ax[1].plot(rel(xx), time, 'bs-', markersize=8)
# ax[1].axis([-50, 5000, -15.9, -14.5])
ax[1].set_ylabel('Time spent on calculation (s)', fontsize=18)
ax[1].set_xlabel('number of atoms $^{3}$', fontsize=18)
# ax[1].set_xscale("log")
ax[1].xaxis.set_tick_params(labelsize=14)
ax[1].yaxis.set_tick_params(labelsize=14)
ax[1].grid(True)
# ax[0].set_title("Paraelectric phase")
ax[1].legend()
# ax[0].set_xticks(xx)

fig.savefig("Excercis3_2")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy as np
import matplotlib.pyplot as plt

xx = np.arange(1, 65)
time = np.array([52.62,25.63,18.78,13.58,11.33,10.2, 8.57, 7.55, 7, 6.54, 6.14, 5.2, 6.04, 5.85, 4.89, 4.91, 5.78, 5.23, 4.85, 5.59, 6, 5.31, 5.19, 5.24, 4.91, 4.67, 4.78, 4.41, 4.27, 4.26, 4.39, 4.06, 3.91, 4.04, 3.80, 3.72, 3.55, 3.81, 3.41, 3.73, 3.52, 3.81, 3.3, 3.24, 3.36, 3.8, 3.6, 3.36, 3.22, 3.22, 3.39, 3.57, 3.08, 3.54, 3.6, 3.35, 3.33, 3.34, 3.07, 3.2, 3.23, 3.21, 2.97, 3.54])
def rel(x):
    return 52.62/x


plt.figure()
plt.plot(xx, rel(time), 'bs-', markersize=6)
plt.plot(xx, xx, 'r-')
plt.rcParams['figure.dpi'] = 400
plt.ylabel('Time spent on calculation (s)', fontsize=14)
plt.xlabel('number of cores',fontsize=14)
# plt.xaxis.set_tick_params(labelsize=14)
# plt.yaxis.set_tick_params(labelsize=14)
plt.grid(True)
# ax[0].set_title("Paraelectric phase")
plt.legend(['actual', 'ideal'])
# ax[0].set_xticks(xx)
plt.savefig("Excercis4_2")
