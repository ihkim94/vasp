# %%
import numpy as np

amu = 1822.8885
M = 35.45 * amu
delta = 0.001
to_eV = 13.6057039763

freq = np.sqrt((2/M) * (-59.99059500 + (-2 * (-59.99059538)) -59.99059534) * (1/(delta**2)))

print(freq*to_eV)
# Out:
# 0.04905378142670799

# %%
import numpy as np

amu = 1822.8885
M = 35.45 * amu
delta = 0.01
to_eV = 13.6057039763

freq = np.sqrt((2/M) * (-59.99057458 + (-2 * (-59.99059538)) -59.99057348) * (1/(delta**2)))

print(freq*to_eV)
# Out:
# 0.04946087335820929

# %%
import numpy as np

amu = 1822.8885
M = 35.45 * amu
delta = 0.002
to_eV = 13.6057039763

freq = np.sqrt((2/M) * (-59.99059395 + (-2 * (-59.99059538)) -59.99059441) * (1/(delta**2)))

print(freq*to_eV)
# Out:
# 0.058630482597676656

# %%
import numpy as np
import matplotlib.pyplot as plt

xx = np.array(["1x1x1", "2x2x2", "3x3x3", "4x4x4", "5x5x5", "6x6x6", "7x7x7", "8x8x8", "9x9x9", "10x10x10"])
energy = np.array([-15.94709113, -17.31445017, -17.32506851, -17.32622361, -17.32640410, -17.32643711, -17.32644761, -17.32644883, -17.32644914, -17.32644953])/2
plt.rcParams['figure.dpi'] = 200
plt.figure()
plt.plot(xx, energy, 'bs-', markersize=8)
# plt.plot(xx, energy_10, 'rs-', markersize=8)
plt.ylabel('Total energy (Ry)', fontsize=14)
plt.xlabel("K-point",fontsize=14)
# plt.xaxis.set_tick_params(labelsize=14)
# plt.yaxis.set_tick_params(labelsize=14)
plt.grid(True)
# ax[0].set_title("Paraelectric phase")
# plt.legend(['100 Ry', '10 Ry'])
# ax[0].set_xticks(xx)
plt.savefig("Excercis2_2")

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(ncols=2, figsize=(20, 12))
fig.dpi = 100


xx = np.arange(10, 210, 10)
energy = np.array([-17.20445508, -17.31753645, -17.32368239, -17.32643725, -17.32694838, -17.32698554, -17.32702497, -17.32704899, -17.32705474, -17.32705513, -17.32705547, -17.32705567, -17.32705625, -17.32705652, -17.32705610, -17.32705646, -17.32705636, -17.32705607, -17.32705564, -17.32705610])/2
ax[0].plot(xx, energy, 'bs-', markersize=8)
# ax[0].axis([0, , -28, -27])
ax[0].set_ylabel('Total energy per atom (Ry)', fontsize=18)
ax[0].set_xlabel('ecutwfc (Ry)',fontsize=18)
ax[0].xaxis.set_tick_params(labelsize=14)
ax[0].yaxis.set_tick_params(labelsize=14)
ax[0].grid(True)
# ax[0].set_title("Paraelectric phase")
ax[0].legend()
# ax[0].set_xticks(xx)

ax[1].plot(xx, energy, 'bs-', markersize=8)
ax[1].axis([30, 200, -8.67, -8.66])
ax[1].set_ylabel('Total energy per atom (Ry)', fontsize=18)
ax[1].set_xlabel('ecutwfc (Ry)', fontsize=18)
ax[1].xaxis.set_tick_params(labelsize=14)
ax[1].yaxis.set_tick_params(labelsize=14)
ax[1].grid(True)
# ax[0].set_title("Paraelectric phase")
ax[1].legend()
# ax[0].set_xticks(xx)

fig.savefig("Excercis2_1")
# fig.suptitle("")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
