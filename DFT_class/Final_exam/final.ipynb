# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(ncols=2, figsize=(22, 12))
fig.dpi = 100

xx = np.arange(10, 210, 10)
energy = np.array([-18.49330, -19.04020532, -19.22087195, -19.29266823, -19.32190641, -19.33383889, -19.33885354, -19.34117518, -19.34220547, -19.34272706, -19.34297882, -19.34311377, -19.34318133, -19.34321813, -19.3432391, -19.34324545, -19.34325182, -19.34325503, -19.34325607, -19.34325761])*(13.6057)/2

ax[0].plot(xx, energy, 'bs-', markersize=8)
# ax[0].axis([0, , -28, -27])
ax[0].set_ylabel('Total energy per atom (eV)', fontsize=18)
ax[0].set_xlabel('ecutwfc (Ry)',fontsize=18)
ax[0].xaxis.set_tick_params(labelsize=14)
ax[0].yaxis.set_tick_params(labelsize=14)
ax[0].grid(True)
# ax[0].set_title("Paraelectric phase")
ax[0].legend()
# ax[0].set_xticks(xx)

ax[1].plot(xx, energy, 'bs-', markersize=8)
ax[1].axis([80, 200, -131.5893, -131.588])
ax[1].set_ylabel('Total energy per atom (eV)', fontsize=18)
ax[1].set_xlabel('ecutwfc (Ry)', fontsize=18)
ax[1].xaxis.set_tick_params(labelsize=14)
ax[1].yaxis.set_tick_params(labelsize=14)
ax[1].grid(True)
# ax[0].set_title("Paraelectric phase")
ax[1].legend()
# ax[0].set_xticks(xx)

fig.savefig("Q1_a")
# fig.suptitle("")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
0.0083*1.3158e2
# Out:
# 1.092114

# %%
import numpy as np
import matplotlib.pyplot as plt

xx = np.array(["1x1x1", "2x2x2", "3x3x3", "4x4x4", "5x5x5", "6x6x6", "7x7x7", "8x8x8", "9x9x9", "10x10x10", "11x11x11", "12x12x12"])
energy = np.array([-19.18027071, -19.33464469, -19.34254617, -19.34314718, -19.34320985, -19.34321710, -19.34321803, -19.34321813, -19.34321821, -19.34321819, -19.34321817, -19.34321821])*(13.6057)/2
plt.rcParams['figure.dpi'] = 200
plt.figure()
plt.plot(xx, energy, 'bs-', markersize=8)
# plt.xlim([min, max])
plt.ylim([-131.5891, -131.588])
# plt.plot(xx, energy_10, 'rs-', markersize=8)
plt.ylabel('Total energy (eV)', fontsize=14)
plt.xlabel("k-point",fontsize=14)
plt.rc('xtick',labelsize=7)
# plt.xaxis.set_tick_params(labelsize=14)
# plt.yaxis.set_tick_params(labelsize=14)
plt.grid(True)
# ax[0].set_title("Paraelectric phase")
# plt.legend(['100 Ry', '10 Ry'])
# ax[0].set_xticks(xx)
plt.savefig("Q1_2")

# %%
import numpy as np
import matplotlib.pyplot as plt

xx = np.arange(8.10, 8.86, 0.05)
energy = np.array([-19.35225960, -19.35348414, -19.35396558, -19.35373957, -19.35284338, -19.3513101, -19.34917397, -19.34646745, -19.3432171, -19.33945657, -19.33521028, -19.33050637, -19.32537262, -19.3198356, -19.3139152, -19.30763836])*(13.6057)/2
plt.rcParams['figure.dpi'] = 200
plt.figure()
plt.plot(xx, energy, 'bs-', markersize=4)
# plt.xlim([min, max])
# plt.ylim([-131.5891, -131.588])
# plt.plot(xx, energy_10, 'rs-', markersize=8)
plt.ylabel('Total energy (eV)', fontsize=14)
plt.xlabel("Lattice constant (Bohr)",fontsize=14)
plt.rc('xtick',labelsize=7)
# plt.xaxis.set_tick_params(labelsize=14)
# plt.yaxis.set_tick_params(labelsize=14)
plt.grid(True)
# ax[0].set_title("Paraelectric phase")
# plt.legend(['100 Ry', '10 Ry'])
# ax[0].set_xticks(xx)
plt.savefig("Q2_1")

# %%
import numpy as np

filename = 'ecut.txt'  # Replace 'your_file.txt' with the actual file path

# Read the file and store lines in a list
with open(filename, 'r') as file:
    lines = file.readlines()

# Extract numbers after the lines containing "total energy"
energy_values = [float(line.split('=')[-1].split()[0]) for line in lines if 'total energy' in line]

# Convert the extracted numbers to a NumPy array
numpy_array = np.array(energy_values)

# Convert the NumPy array to a string with commas
result_string = ', '.join(map(str, numpy_array))

# Print the result
print(result_string)
# Out:
# -19.35348414, -19.35396558, -19.35373957, -19.35284338, -19.3513101, -19.34917397, -19.34646745, -19.3432171, -19.33945657, -19.33521028, -19.33050637, -19.32537262, -19.3198356, -19.3139152, -19.30763836

# %%
8.5 * (0.482846/0.5)
# Out:
# 8.208382

# %%
np.array([-19.35396558, -19.35397669])*(13.6057)/2
# Out:
# array([-131.66212475, -131.66220033])

# %%
[-19.35306414, -19.35397601, -19.35299906]
term = ((-19.35306414 + (-2*-19.35397601) -19.35299906))/(0.01**2)
B = (1/9) * (1/138.2651) * term * 14710.5
B
# Out:
# 223.28673613241514

# %%
9.39134-10.75216
# Out:
# -1.3608200000000004

# %%
6.14477-1.54753
# Out:
# 4.59724
