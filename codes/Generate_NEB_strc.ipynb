  0.3140482927581593  0.1570241463790797  0.9475096582125258   T   T   T
  0.4964448424839084  0.9928896849678097  0.6516905261873257   T   T   T
  0.4964448424839084  0.5035551575160916  0.6516905261873257   T   T   T
  0.0071103150321905  0.5035551575160916  0.6516905261873257   T   T   T
  0.5031177371414471  0.0062354742829015  0.3489299100785765   T   T   T
  0.5031177371414471  0.4968822628585529  0.3489299100785765   T   T   T
  0.9937645257170986  0.4968822628585529  0.3489299100785765   T   T   T
  0.5035551575160916  0.0071103150321905  0.1516905261873255   T   T   T
  0.5035551575160916  0.4964448424839084  0.1516905261873255   T   T   T
  0.9928896849678097  0.4964448424839084  0.1516905261873255   T   T   T
  0.4968822628585529  0.9937645257170986  0.8489299100785767   T   T   T
  0.4968822628585529  0.5031177371414471  0.8489299100785767   T   T   T
  0.0062354742829015  0.5031177371414471  0.8489299100785767   T   T   T
  0.3333333333330017  0.6666666666669983  0.7448882565787118   T   T   T
  0.6666666666669983  0.3333333333330017  0.2448882565787118   T   T   T
"""

# Split the data into lines
lines = data.split('\n')

# Remove the letter 'T' from each line and create a NumPy array
new_data_fin = np.array([list(map(float, line.split()[:-3])) for line in lines if line])

print(new_data_fin)
# Out:
# [[ 6.66666667e-01  3.33333333e-01  5.24389549e-01]
#  [ 3.33333333e-01  6.66666667e-01  4.75994163e-01]
#  [ 3.33333333e-01  6.66666667e-01  2.43895489e-02]
#  [ 6.66666667e-01  3.33333333e-01  9.75994163e-01]
#  [ 0.00000000e+00 -0.00000000e+00  5.00231863e-01]
#  [ 0.00000000e+00 -0.00000000e+00  2.31862583e-04]
#  [ 6.66666667e-01  3.33333333e-01  6.91560296e-01]
#  [ 3.33333333e-01  6.66666667e-01  3.08464141e-01]
#  [ 3.33333333e-01  6.66666667e-01  1.91560296e-01]
#  [ 6.66666667e-01  3.33333333e-01  8.08464141e-01]
#  [ 8.30395440e-01  6.60790879e-01  3.92049300e-01]
#  [ 8.30395440e-01  1.69604560e-01  3.92049300e-01]
#  [ 3.39209121e-01  1.69604560e-01  3.92049300e-01]
#  [ 1.68068108e-01  3.36136216e-01  6.08538337e-01]
#  [ 1.68068108e-01  8.31931892e-01  6.08538337e-01]
#  [ 6.63863784e-01  8.31931892e-01  6.08538337e-01]
#  [ 1.69604560e-01  3.39209121e-01  8.92049300e-01]
#  [ 1.69604560e-01  8.30395440e-01  8.92049300e-01]
# ...

# %%
import numpy as np

def linear_interpolate(initial_data, final_data, steps):
    initial_array = np.array(initial_data)
    final_array = np.array(final_data)

    # Check if the shapes of the arrays match
    if initial_array.shape != final_array.shape:
        raise ValueError("Initial and final data shapes must be the same.")

    # Linearly interpolate between initial and final data
    interpolated_data = []
    for step in range(steps + 1):
        alpha = step / steps
        interpolated_point = (1 - alpha) * initial_array + alpha * final_array
        interpolated_data.append(interpolated_point)

    return np.array(interpolated_data)

# Example data
initial_data = new_data_ini

final_data = new_data_fin

# Number of interpolation steps
num_steps = 6

# Perform linear interpolation
interpolated_data = linear_interpolate(initial_data, final_data, num_steps)

# Display the result
for step, data_point in enumerate(interpolated_data):
    print(f"Step {step}: {data_point}")
# Out:
# Step 0: [[ 0.66666667  0.33333333  0.53000487]
#  [ 0.33333333  0.66666667  0.46999513]
#  [ 0.33333333  0.66666667  0.03000487]
#  [ 0.66666667  0.33333333  0.96999513]
#  [ 0.         -0.          0.5       ]
#  [ 0.         -0.          0.        ]
#  [ 0.66666667  0.33333333  0.69064333]
#  [ 0.33333333  0.66666667  0.30935667]
#  [ 0.33333333  0.66666667  0.19064333]
#  [ 0.66666667  0.33333333  0.80935667]
#  [ 0.83102916  0.66205832  0.39076137]
#  [ 0.83102916  0.16897084  0.39076137]
#  [ 0.33794168  0.16897084  0.39076137]
#  [ 0.16897084  0.33794168  0.60923863]
#  [ 0.16897084  0.83102916  0.60923863]
#  [ 0.66205832  0.83102916  0.60923863]
#  [ 0.16897084  0.33794168  0.89076137]
#  [ 0.16897084  0.83102916  0.89076137]
#  [ 0.66205832  0.83102916  0.89076137]
#  [ 0.83102916  0.66205832  0.10923863]
#  [ 0.83102916  0.16897084  0.10923863]
#  [ 0.33794168  0.16897084  0.10923863]
#  [ 0.         -0.          0.75      ]
#  [ 0.         -0.          0.25      ]
# ...

# %%
import numpy as np

def linear_interpolate(initial_data, final_data, steps):
    initial_array = np.array(initial_data)
    final_array = np.array(final_data)

    # Check if the shapes of the arrays match
    if initial_array.shape != final_array.shape:
        raise ValueError("Initial and final data shapes must be the same.")

    # Linearly interpolate between initial and final data
    interpolated_data = []
    for step in range(steps + 1):
        alpha = step / steps
        interpolated_point = (1 - alpha) * initial_array + alpha * final_array
        interpolated_data.append(interpolated_point)

    return np.array(interpolated_data)

# Example data
initial_data = new_data_ini

final_data = new_data_fin

# Number of interpolation steps
num_steps = 7

# Perform linear interpolation
interpolated_data = linear_interpolate(initial_data, final_data, num_steps)

# Display the result
for step, data_point in enumerate(interpolated_data):
    print("Image:", step)
    formatted_data = str(data_point).replace('[', '').replace(']', '')
    print(formatted_data)
# Out:
# Image: 0
#  0.66666667  0.33333333  0.53000487
#   0.33333333  0.66666667  0.46999513
#   0.33333333  0.66666667  0.03000487
#   0.66666667  0.33333333  0.96999513
#   0.         -0.          0.5
#   0.         -0.          0.
#   0.66666667  0.33333333  0.69064333
#   0.33333333  0.66666667  0.30935667
#   0.33333333  0.66666667  0.19064333
#   0.66666667  0.33333333  0.80935667
#   0.83102916  0.66205832  0.39076137
#   0.83102916  0.16897084  0.39076137
#   0.33794168  0.16897084  0.39076137
#   0.16897084  0.33794168  0.60923863
#   0.16897084  0.83102916  0.60923863
#   0.66205832  0.83102916  0.60923863
#   0.16897084  0.33794168  0.89076137
#   0.16897084  0.83102916  0.89076137
#   0.66205832  0.83102916  0.89076137
#   0.83102916  0.66205832  0.10923863
#   0.83102916  0.16897084  0.10923863
#   0.33794168  0.16897084  0.10923863
#   0.         -0.          0.75
#   0.         -0.          0.25
#   0.33333333  0.66666667  0.55488024
#   0.66666667  0.33333333  0.44511976
# ...
