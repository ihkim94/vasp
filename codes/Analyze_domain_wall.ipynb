# %%
import numpy as np
import matplotlib.pyplot as plt

"""
   
    Analyzing domain wall structure
    
"""

n_bulk = 4  ## This number has to be confirmed later, might has to be tested later for the convergence.
n_DW = 3  ## The size of the unit cell.
n_unit = 2*n_bulk + 2*n_DW ## number of atoms for each sort of atom.

file_name = "VASP_files/POSCAR_3"
# file_name = "VASP_files/POSCAR_PBEsol"
poscar = Poscar.from_file(file_name)
struc = poscar.structure

def get_z_Ti(struc):
    list_z = []
    for i in range(n_unit, 2*n_unit):
        list_z.append(struc.frac_coords[i][2]-0.5)
    return list_z

def get_z_Ba(struc):
    list_z = []
    for i in range(0, n_unit):
        list_z.append(struc.frac_coords[i][2])
    return list_z


xx = np.arange(0, n_unit)
Ti_disp = get_z_Ti(struc)
Ba_disp = get_z_Ba(struc)


plt.figure(figsize=(20,8))
plt.plot(xx, Ti_disp, 'bs-', markersize=8)
plt.plot(xx, Ba_disp, 'rs-', markersize=8)
# plt.rcParams['figure.dpi'] = 200
plt.ylabel('Atomic displacements', fontsize=14)
plt.xlabel('unit cell',fontsize=14)
plt.ylim(-0.025, 0.025)
# plt.xaxis.set_tick_params(labelsize=14)
# plt.yaxis.set_tick_params(labelsize=14)
plt.grid(True)
plt.legend(['Ti displacement', 'Ba displacement'])

# plt.savefig("Excercis2_3")

# %%
import numpy as np
import matplotlib.pyplot as plt

"""
   
    Analyzing domain wall structure
    
"""

n_bulk = 4  ## This number has to be confirmed later, might has to be tested later for the convergence.
n_DW = 15  ## The size of the unit cell.
n_unit = 2*n_bulk + 2*n_DW ## number of atoms for each sort of atom.

file_name = "VASP_files/POSCAR_15_PBEsol_free"
# file_name = "VASP_files/POSCAR_PBEsol"
poscar = Poscar.from_file(file_name)
struc = poscar.structure

def get_z_Ti(struc):
    list_z = []
    for i in range(n_unit, 2*n_unit):
        list_z.append(struc.frac_coords[i][2]-0.5)
    return list_z

def get_z_Ba(struc):
    list_z = []
    for i in range(0, n_unit):
        list_z.append(struc.frac_coords[i][2])
    return list_z


xx = np.arange(0, n_unit)
Ti_disp = get_z_Ti(struc)
Ba_disp = get_z_Ba(struc)


plt.figure(figsize=(20,8))
plt.plot(xx, Ti_disp, 'bs-', markersize=8)
plt.plot(xx, Ba_disp, 'rs-', markersize=8)
# plt.rcParams['figure.dpi'] = 200
plt.ylabel('Atomic displacements', fontsize=14)
plt.xlabel('unit cell',fontsize=14)
plt.ylim(-0.025, 0.025)
# plt.xaxis.set_tick_params(labelsize=14)
# plt.yaxis.set_tick_params(labelsize=14)
plt.grid(True)
plt.legend(['Ti displacement', 'Ba displacement'])

# plt.savefig("Excercis2_3")
